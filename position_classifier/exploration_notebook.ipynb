# %%
import polars as pl
import chess
import torch
import torch.nn as nn
import numpy as np
import json

# %%
# print all rows and columns of a Polars DataFrame
pl.Config.set_tbl_rows(100)
pl.Config.set_tbl_cols(100)
# Out:
# polars.config.Config

# %%
raw_data=pl.read_csv("data/raw/lichess_db_puzzle.csv")
raw_data.describe
# Out:
# <bound method DataFrame.describe of shape: (5_682_618, 10)
# ┌─────────┬─────────┬─────────┬────────┬─────────┬─────────┬─────────┬─────────┬─────────┬─────────┐
# │ PuzzleI ┆ FEN     ┆ Moves   ┆ Rating ┆ RatingD ┆ Popular ┆ NbPlays ┆ Themes  ┆ GameUrl ┆ Opening │
# │ d       ┆ ---     ┆ ---     ┆ ---    ┆ eviatio ┆ ity     ┆ ---     ┆ ---     ┆ ---     ┆ Tags    │
# │ ---     ┆ str     ┆ str     ┆ i64    ┆ n       ┆ ---     ┆ i64     ┆ str     ┆ str     ┆ ---     │
# │ str     ┆         ┆         ┆        ┆ ---     ┆ i64     ┆         ┆         ┆         ┆ str     │
# │         ┆         ┆         ┆        ┆ i64     ┆         ┆         ┆         ┆         ┆         │
# ╞═════════╪═════════╪═════════╪════════╪═════════╪═════════╪═════════╪═════════╪═════════╪═════════╡
# │ 00008   ┆ r6k/pp2 ┆ f2g3    ┆ 1829   ┆ 76      ┆ 95      ┆ 8958    ┆ crushin ┆ https:/ ┆ null    │
# │         ┆ r2p/4Rp ┆ e6e7    ┆        ┆         ┆         ┆         ┆ g hangi ┆ /liches ┆         │
# │         ┆ 1Q/3p4/ ┆ b2b1    ┆        ┆         ┆         ┆         ┆ ngPiece ┆ s.org/7 ┆         │
# │         ┆ 8/1N1P2 ┆ b3c1    ┆        ┆         ┆         ┆         ┆ long    ┆ 87zsVup ┆         │
# │         ┆ R1…     ┆ b1c1    ┆        ┆         ┆         ┆         ┆ mid…    ┆ /b…     ┆         │
# │         ┆         ┆ h6c1    ┆        ┆         ┆         ┆         ┆         ┆         ┆         │
# │ 0000D   ┆ 5rk1/1p ┆ d3d6    ┆ 1473   ┆ 75      ┆ 96      ┆ 35195   ┆ advanta ┆ https:/ ┆ null    │
# │         ┆ 3ppp/pq ┆ f8d8    ┆        ┆         ┆         ┆         ┆ ge      ┆ /liches ┆         │
# │         ┆ 3b2/8/8 ┆ d6d8    ┆        ┆         ┆         ┆         ┆ endgame ┆ s.org/F ┆         │
# │         ┆ /1P1Q1N ┆ f6d8    ┆        ┆         ┆         ┆         ┆ short   ┆ 8M8OS71 ┆         │
# │         ┆ 2/…     ┆         ┆        ┆         ┆         ┆         ┆         ┆ #5…     ┆         │
# │ 0008Q   ┆ 8/4R3/1 ┆ e7f7    ┆ 1367   ┆ 78      ┆ 91      ┆ 748     ┆ advanta ┆ https:/ ┆ null    │
# │         ┆ p2P3/p4 ┆ f5e5    ┆        ┆         ┆         ┆         ┆ ge      ┆ /liches ┆         │
# │         ┆ r2/P6p/ ┆ e2f1    ┆        ┆         ┆         ┆         ┆ endgame ┆ s.org/M ┆         │
# │         ┆ 1P3Pk1/ ┆ e5e6    ┆        ┆         ┆         ┆         ┆ rookEnd ┆ QSyb3KW ┆         │
# │         ┆ 4K…     ┆         ┆        ┆         ┆         ┆         ┆ game …  ┆ #1…     ┆         │
# │ 0009B   ┆ r2qr1k1 ┆ b6c5    ┆ 1103   ┆ 74      ┆ 88      ┆ 604     ┆ advanta ┆ https:/ ┆ Kings_P │
# │         ┆ /b1p2pp ┆ e2g4    ┆        ┆         ┆         ┆         ┆ ge midd ┆ /liches ┆ awn_Gam │
# │         ┆ p/pp4n1 ┆ h3g4    ┆        ┆         ┆         ┆         ┆ legame  ┆ s.org/4 ┆ e Kings │
# │         ┆ /P1P1p3 ┆ d1g4    ┆        ┆         ┆         ┆         ┆ short   ┆ MWQCxQ6 ┆ _Pawn_G │
# │         ┆ /4…     ┆         ┆        ┆         ┆         ┆         ┆         ┆ /b…     ┆ am…     │
# │ 000Pw   ┆ 6k1/5p1 ┆ e4d2    ┆ 1522   ┆ 75      ┆ 92      ┆ 614     ┆ crushin ┆ https:/ ┆ null    │
# │         ┆ p/4p3/4 ┆ d4e2    ┆        ┆         ┆         ┆         ┆ g       ┆ /liches ┆         │
# │         ┆ q3/3nN3 ┆ g1f1    ┆        ┆         ┆         ┆         ┆ endgame ┆ s.org/a ┆         │
# │         ┆ /2Q3P1/ ┆ e2c3    ┆        ┆         ┆         ┆         ┆ fork    ┆ u2lCK5o ┆         │
# │         ┆ PP…     ┆         ┆        ┆         ┆         ┆         ┆ short   ┆ #7…     ┆         │
# │ 000Sa   ┆ 2Q2bk1/ ┆ c4c2    ┆ 1471   ┆ 75      ┆ 96      ┆ 427     ┆ advanta ┆ https:/ ┆ null    │
# │         ┆ 5p1p/p5 ┆ e4c2    ┆        ┆         ┆         ┆         ┆ ge      ┆ /liches ┆         │
# │         ┆ p1/2p3P ┆ a2a1    ┆        ┆         ┆         ┆         ┆ endgame ┆ s.org/l ┆         │
# │         ┆ 1/2r1B3 ┆ c2b1    ┆        ┆         ┆         ┆         ┆ short   ┆ TTa9lwd ┆         │
# │         ┆ /7…     ┆         ┆        ┆         ┆         ┆         ┆         ┆ /b…     ┆         │
# │ 000VW   ┆ r4r2/1p ┆ g6f5    ┆ 2861   ┆ 108     ┆ 85      ┆ 276     ┆ crushin ┆ https:/ ┆ null    │
# │         ┆ 3pkp/p5 ┆ d5c5    ┆        ┆         ┆         ┆         ┆ g       ┆ /liches ┆         │
# │         ┆ p1/3R1N ┆ c2e4    ┆        ┆         ┆         ┆         ┆ endgame ┆ s.org/e ┆         │
# │         ┆ 1Q/3P4/ ┆ h5g5    ┆        ┆         ┆         ┆         ┆ long    ┆ 9AY2m5j ┆         │
# │         ┆ 8/…     ┆ g7h8    ┆        ┆         ┆         ┆         ┆         ┆ /b…     ┆         │
# │         ┆         ┆ g5f6    ┆        ┆         ┆         ┆         ┆         ┆         ┆         │
# │ 000Vc   ┆ 8/8/4k1 ┆ g4h5    ┆ 1611   ┆ 80      ┆ 75      ┆ 108     ┆ crushin ┆ https:/ ┆ null    │
# │         ┆ p1/2KpP ┆ g6h5    ┆        ┆         ┆         ┆         ┆ g       ┆ /liches ┆         │
# │         ┆ 2p/5PP1 ┆ f4f5    ┆        ┆         ┆         ┆         ┆ endgame ┆ s.org/l ┆         │
# │         ┆ /8/8/8  ┆ e6e5    ┆        ┆         ┆         ┆         ┆ long    ┆ 6AejDMO ┆         │
# │         ┆ w …     ┆ f5f6    ┆        ┆         ┆         ┆         ┆ pawnEnd ┆ #1…     ┆         │
# │         ┆         ┆ e5f6    ┆        ┆         ┆         ┆         ┆ g…      ┆         ┆         │
# │ 000Zo   ┆ 4r3/1k6 ┆ e5f6    ┆ 1376   ┆ 75      ┆ 86      ┆ 649     ┆ endgame ┆ https:/ ┆ null    │
# │         ┆ /pp3r2/ ┆ e8e1    ┆        ┆         ┆         ┆         ┆ mate    ┆ /liches ┆         │
# │         ┆ 1b2P2p/ ┆ g1f2    ┆        ┆         ┆         ┆         ┆ mateIn2 ┆ s.org/n ┆         │
# │         ┆ 3R1p2/P ┆ e1f1    ┆        ┆         ┆         ┆         ┆ operaMa ┆ 8Ff742v ┆         │
# │         ┆ 1R…     ┆         ┆        ┆         ┆         ┆         ┆ te…     ┆ #6…     ┆         │
# │ 000aY   ┆ r4rk1/p ┆ g5e7    ┆ 1414   ┆ 78      ┆ 75      ┆ 526     ┆ advanta ┆ https:/ ┆ Benoni_ │
# │         ┆ p3ppp/2 ┆ a5c3    ┆        ┆         ┆         ┆         ┆ ge      ┆ /liches ┆ Defense │
# │         ┆ n1b3/q1 ┆ b2c3    ┆        ┆         ┆         ┆         ┆ master  ┆ s.org/i ┆ Benoni_ │
# │         ┆ pp2B1/8 ┆ c6e7    ┆        ┆         ┆         ┆         ┆ middleg ┆ ihZGl6t ┆ Defense │
# │         ┆ /P…     ┆         ┆        ┆         ┆         ┆         ┆ ame sh… ┆ #2…     ┆ _…      │
# │ 000h0   ┆ 5rk1/p5 ┆ e4e6    ┆ 2066   ┆ 75      ┆ 89      ┆ 187     ┆ advanta ┆ https:/ ┆ null    │
# │         ┆ p1/3bpr ┆ f6f3    ┆        ┆         ┆         ┆         ┆ ge inte ┆ /liches ┆         │
# │         ┆ 1p/1Pp4 ┆ g2f3    ┆        ┆         ┆         ┆         ┆ rferenc ┆ s.org/O ┆         │
# │         ┆ q/3pR3/ ┆ h5h2    ┆        ┆         ┆         ┆         ┆ e kings ┆ We6M5dF ┆         │
# │         ┆ 1P…     ┆ g1f1    ┆        ┆         ┆         ┆         ┆ id…     ┆ #4…     ┆         │
# │         ┆         ┆ h2h3 …  ┆        ┆         ┆         ┆         ┆         ┆         ┆         │
# │ 000hf   ┆ r1bqk2r ┆ e8f7    ┆ 1661   ┆ 77      ┆ 92      ┆ 690     ┆ mate    ┆ https:/ ┆ Horwitz │
# │         ┆ /pp1nbN ┆ e2e6    ┆        ┆         ┆         ┆         ┆ mateIn2 ┆ /liches ┆ _Defens │
# │         ┆ p1/2p1p ┆ f7f8    ┆        ┆         ┆         ┆         ┆ middleg ┆ s.org/7 ┆ e Horwi │
# │         ┆ 2p/8/2B ┆ e6f7    ┆        ┆         ┆         ┆         ┆ ame     ┆ 1ygsFeE ┆ tz_Defe │
# │         ┆ P4…     ┆         ┆        ┆         ┆         ┆         ┆ short   ┆ /b…     ┆ ns…     │
# │ 000jr   ┆ 5k2/1p4 ┆ f8g8    ┆ 2136   ┆ 77      ┆ 69      ┆ 90      ┆ crushin ┆ https:/ ┆ null    │
# │         ┆ pp/p5n1 ┆ f5d5    ┆        ┆         ┆         ┆         ┆ g       ┆ /liches ┆         │
# │         ┆ /5Q2/3B ┆ g8f8    ┆        ┆         ┆         ┆         ┆ endgame ┆ s.org/J ┆         │
# │         ┆ pP2/1P2 ┆ d4c5    ┆        ┆         ┆         ┆         ┆ long    ┆ gxFj109 ┆         │
# │         ┆ PP…     ┆ c2c5    ┆        ┆         ┆         ┆         ┆         ┆ /b…     ┆         │
# │         ┆         ┆ d5c5    ┆        ┆         ┆         ┆         ┆         ┆         ┆         │
# │ 000lC   ┆ 3r3r/pQ ┆ d1d6    ┆ 1434   ┆ 75      ┆ 94      ┆ 4523    ┆ advanta ┆ https:/ ┆ null    │
# │         ┆ Nk1ppp/ ┆ d7d6    ┆        ┆         ┆         ┆         ┆ ge hang ┆ /liches ┆         │
# │         ┆ 1qnb1n2 ┆ b7b6    ┆        ┆         ┆         ┆         ┆ ingPiec ┆ s.org/v ┆         │
# │         ┆ /1B6/8/ ┆ a7b6    ┆        ┆         ┆         ┆         ┆ e middl ┆ aqz2bx6 ┆         │
# │         ┆ 8/…     ┆         ┆        ┆         ┆         ┆         ┆ eg…     ┆ #3…     ┆         │
# │ 000mr   ┆ 5r1k/5r ┆ e3g3    ┆ 1957   ┆ 84      ┆ 62      ┆ 104     ┆ crushin ┆ https:/ ┆ null    │
# │         ┆ p1/p7/1 ┆ f7f4    ┆        ┆         ┆         ┆         ┆ g middl ┆ /liches ┆         │
# │         ┆ b2B2p/1 ┆ e5f4    ┆        ┆         ┆         ┆         ┆ egame   ┆ s.org/8 ┆         │
# │         ┆ P1P1Pq1 ┆ f8f4    ┆        ┆         ┆         ┆         ┆ short   ┆ sVpuwso ┆         │
# │         ┆ /2…     ┆         ┆        ┆         ┆         ┆         ┆         ┆ #8…     ┆         │
# │ 000o3   ┆ 8/2p1k3 ┆ e7d6    ┆ 944    ┆ 77      ┆ 87      ┆ 184     ┆ crushin ┆ https:/ ┆ null    │
# │         ┆ /6p1/1p ┆ d3d4    ┆        ┆         ┆         ┆         ┆ g       ┆ /liches ┆         │
# │         ┆ 1P1p2/1 ┆ g6g5    ┆        ┆         ┆         ┆         ┆ endgame ┆ s.org/B ┆         │
# │         ┆ P3P2/3K ┆ f4g5    ┆        ┆         ┆         ┆         ┆ pawnEnd ┆ AY91mF3 ┆         │
# │         ┆ 2P…     ┆         ┆        ┆         ┆         ┆         ┆ game s… ┆ /b…     ┆         │
# │ 000qP   ┆ 8/7R/8/ ┆ f2f1    ┆ 2003   ┆ 78      ┆ 92      ┆ 983     ┆ crushin ┆ https:/ ┆ null    │
# │         ┆ 5p2/4bk ┆ f4f3    ┆        ┆         ┆         ┆         ┆ g       ┆ /liches ┆         │
# │         ┆ 1P/8/2r ┆ f1e1    ┆        ┆         ┆         ┆         ┆ endgame ┆ s.org/r ┆         │
# │         ┆ 2K2/6R1 ┆ c2c1    ┆        ┆         ┆         ┆         ┆ exposed ┆ 4xUR6fC ┆         │
# │         ┆ w…      ┆ e1d2    ┆        ┆         ┆         ┆         ┆ King l… ┆ #1…     ┆         │
# │         ┆         ┆ c1g1    ┆        ┆         ┆         ┆         ┆         ┆         ┆         │
# │ 000rO   ┆ 3R4/8/K ┆ a6a5    ┆ 1110   ┆ 82      ┆ 85      ┆ 70      ┆ crushin ┆ https:/ ┆ null    │
# │         ┆ 7/pB2b3 ┆ e5c7    ┆        ┆         ┆         ┆         ┆ g       ┆ /liches ┆         │
# │         ┆ /1p6/1P ┆ a5b4    ┆        ┆         ┆         ┆         ┆ endgame ┆ s.org/t ┆         │
# │         ┆ 2k3/3p4 ┆ c7d8    ┆        ┆         ┆         ┆         ┆ fork    ┆ zeeBEc2 ┆         │
# │         ┆ /8…     ┆         ┆        ┆         ┆         ┆         ┆ master  ┆ #1…     ┆         │
# │         ┆         ┆         ┆        ┆         ┆         ┆         ┆ s…      ┆         ┆         │
# │ 000rZ   ┆ 2kr1b1r ┆ d4e6    ┆ 923    ┆ 91      ┆ 100     ┆ 400     ┆ kingsid ┆ https:/ ┆ Scandin │
# │         ┆ /p1p2pp ┆ d6h2    ┆        ┆         ┆         ┆         ┆ eAttack ┆ /liches ┆ avian_D │
# │         ┆ 1/2pqb3 ┆         ┆        ┆         ┆         ┆         ┆ mate    ┆ s.org/s ┆ efense  │
# │         ┆ /7p/3N2 ┆         ┆        ┆         ┆         ┆         ┆ mateIn1 ┆ eIMDWkD ┆ Scandin │
# │         ┆ n1…     ┆         ┆        ┆         ┆         ┆         ┆ on…     ┆ #2…     ┆ av…     │
# │ 00143   ┆ r2q1rk1 ┆ d8f6    ┆ 1814   ┆ 76      ┆ 91      ┆ 2882    ┆ advanta ┆ https:/ ┆ Scotch_ │
# │         ┆ /5ppp/1 ┆ d1h5    ┆        ┆         ┆         ┆         ┆ ge midd ┆ /liches ┆ Game    │
# │         ┆ np5/p1b ┆ h7h6    ┆        ┆         ┆         ┆         ┆ legame  ┆ s.org/j ┆ Scotch_ │
# │         ┆ 5/2p1B3 ┆ h5c5    ┆        ┆         ┆         ┆         ┆ short   ┆ cuxlI63 ┆ Game_Mi │
# │         ┆ /P…     ┆         ┆        ┆         ┆         ┆         ┆         ┆ /b…     ┆ eses…   │
# │ 0017R   ┆ r2qk2r/ ┆ e5c4    ┆ 1548   ┆ 76      ┆ 96      ┆ 4226    ┆ advanta ┆ https:/ ┆ Alekhin │
# │         ┆ pp2ppbp ┆ d3c4    ┆        ┆         ┆         ┆         ┆ ge fork ┆ /liches ┆ e_Defen │
# │         ┆ /1n1p2p ┆ b6c4    ┆        ┆         ┆         ┆         ┆ long    ┆ s.org/o ┆ se Alek │
# │         ┆ 1/3Pn3/ ┆ d1a4    ┆        ┆         ┆         ┆         ┆ middleg ┆ l84k0z4 ┆ hine_De │
# │         ┆ 2P…     ┆ d8d7    ┆        ┆         ┆         ┆         ┆ ame     ┆ /b…     ┆ fe…     │
# │         ┆         ┆ a4c4    ┆        ┆         ┆         ┆         ┆         ┆         ┆         │
# │ 0018P   ┆ 5R2/1p6 ┆ f5e6    ┆ 1765   ┆ 74      ┆ 90      ┆ 204     ┆ crushin ┆ https:/ ┆ null    │
# │         ┆ /p1p5/2 ┆ f8e8    ┆        ┆         ┆         ┆         ┆ g       ┆ /liches ┆         │
# │         ┆ P1rk2/2 ┆ e6f5    ┆        ┆         ┆         ┆         ┆ endgame ┆ s.org/X ┆         │
# │         ┆ K3p1/2P ┆ e8e5    ┆        ┆         ┆         ┆         ┆ exposed ┆ g1Gtfjr ┆         │
# │         ┆ 1p…     ┆ f5e5    ┆        ┆         ┆         ┆         ┆ King r… ┆ /b…     ┆         │
# │         ┆         ┆ c4d3 …  ┆        ┆         ┆         ┆         ┆         ┆         ┆         │
# │ 0018S   ┆ 2kr3r/p ┆ b7b6    ┆ 2584   ┆ 111     ┆ 90      ┆ 1806    ┆ advanta ┆ https:/ ┆ null    │
# │         ┆ p3p2/4p ┆ d4a1    ┆        ┆         ┆         ┆         ┆ ge      ┆ /liches ┆         │
# │         ┆ 2p/1N1p ┆ a7a5    ┆        ┆         ┆         ┆         ┆ endgame ┆ s.org/H ┆         │
# │         ┆ 2p1/3Q4 ┆ f1c1    ┆        ┆         ┆         ┆         ┆ pin     ┆ 1ARO2GL ┆         │
# │         ┆ /1…     ┆         ┆        ┆         ┆         ┆         ┆ short   ┆ /b…     ┆         │
# │ 001Fg   ┆ 2R2r1k/ ┆ c8c7    ┆ 1446   ┆ 76      ┆ 94      ┆ 1439    ┆ advanta ┆ https:/ ┆ null    │
# │         ┆ pQ4pp/5 ┆ d4e2    ┆        ┆         ┆         ┆         ┆ ge midd ┆ /liches ┆         │
# │         ┆ rp1/3B4 ┆ g1h2    ┆        ┆         ┆         ┆         ┆ legame  ┆ s.org/y ┆         │
# │         ┆ /q2n4/7 ┆ a4f4    ┆        ┆         ┆         ┆         ┆ veryLon ┆ 0QalMAw ┆         │
# │         ┆ P/…     ┆ h2h1    ┆        ┆         ┆         ┆         ┆ g       ┆ #5…     ┆         │
# │         ┆         ┆ e2g3 …  ┆        ┆         ┆         ┆         ┆         ┆         ┆         │
# │ 001Hi   ┆ 6k1/pp1 ┆ b6d4    ┆ 2389   ┆ 115     ┆ 58      ┆ 20      ┆ advanta ┆ https:/ ┆ null    │
# │         ┆ r1pp1/1 ┆ f4f6    ┆        ┆         ┆         ┆         ┆ ge      ┆ /liches ┆         │
# │         ┆ qp1p2p/ ┆ d4f2    ┆        ┆         ┆         ┆         ┆ endgame ┆ s.org/t ┆         │
# │         ┆ 4P2P/5Q ┆ f6f2    ┆        ┆         ┆         ┆         ┆ long    ┆ UkE0z1z ┆         │
# │         ┆ 2/…     ┆ d2f2    ┆        ┆         ┆         ┆         ┆ pin     ┆ /b…     ┆         │
# │         ┆         ┆ g1f2    ┆        ┆         ┆         ┆         ┆         ┆         ┆         │
# │ 001KR   ┆ 6Qk/p1p ┆ h8g8    ┆ 552    ┆ 83      ┆ 100     ┆ 124     ┆ mate    ┆ https:/ ┆ null    │
# │         ┆ 3pp/4N3 ┆ f1f8    ┆        ┆         ┆         ┆         ┆ mateIn1 ┆ /liches ┆         │
# │         ┆ /1p6/2q ┆         ┆        ┆         ┆         ┆         ┆ middleg ┆ s.org/T ┆         │
# │         ┆ 1r1n1/2 ┆         ┆        ┆         ┆         ┆         ┆ ame     ┆ aT1Zl7z ┆         │
# │         ┆ B5…     ┆         ┆        ┆         ┆         ┆         ┆ oneMov… ┆ /b…     ┆         │
# │ 001Oo   ┆ 6k1/4p1 ┆ d1a4    ┆ 2078   ┆ 78      ┆ 84      ┆ 61      ┆ crushin ┆ https:/ ┆ null    │
# │         ┆ bp/6p1/ ┆ a2a4    ┆        ┆         ┆         ┆         ┆ g       ┆ /liches ┆         │
# │         ┆ 1p1pP3/ ┆ b5a4    ┆        ┆         ┆         ┆         ┆ endgame ┆ s.org/8 ┆         │
# │         ┆ 1PpPp3/ ┆ b4b5    ┆        ┆         ┆         ┆         ┆ long    ┆ IKs77O9 ┆         │
# │         ┆ 2P…     ┆ g8f7    ┆        ┆         ┆         ┆         ┆ quietMo ┆ /b…     ┆         │
# │         ┆         ┆ b5b6    ┆        ┆         ┆         ┆         ┆ v…      ┆         ┆         │
# │ 001Wz   ┆ 4r1k1/5 ┆ e8e5    ┆ 1118   ┆ 82      ┆ 89      ┆ 81      ┆ backRan ┆ https:/ ┆ null    │
# │         ┆ ppp/r1p ┆ d1d8    ┆        ┆         ┆         ┆         ┆ kMate   ┆ /liches ┆         │
# │         ┆ 5/p1n1R ┆ e5e8    ┆        ┆         ┆         ┆         ┆ endgame ┆ s.org/8 ┆         │
# │         ┆ P2/8/2P ┆ d8e8    ┆        ┆         ┆         ┆         ┆ mate    ┆ 4RH3LaP ┆         │
# │         ┆ 2N…     ┆         ┆        ┆         ┆         ┆         ┆ mate…   ┆ /b…     ┆         │
# │ 001XA   ┆ 1qr2rk1 ┆ b8c7    ┆ 1656   ┆ 75      ┆ 91      ┆ 1339    ┆ crushin ┆ https:/ ┆ null    │
# │         ┆ /pb2bpp ┆ b1b7    ┆        ┆         ┆         ┆         ┆ g disco ┆ /liches ┆         │
# │         ┆ p/8/8/2 ┆ c7b7    ┆        ┆         ┆         ┆         ┆ veredAt ┆ s.org/K ┆         │
# │         ┆ p1N3/P1 ┆ e4f6    ┆        ┆         ┆         ┆         ┆ tack    ┆ ZRiN695 ┆         │
# │         ┆ Bn…     ┆ e7f6    ┆        ┆         ┆         ┆         ┆ long…   ┆ /b…     ┆         │
# │         ┆         ┆ g2b7    ┆        ┆         ┆         ┆         ┆         ┆         ┆         │
# │ 001aK   ┆ 6k1/5p2 ┆ d2e2    ┆ 1978   ┆ 76      ┆ 91      ┆ 295     ┆ crushin ┆ https:/ ┆ null    │
# │         ┆ /4p3/P1 ┆ f1e2    ┆        ┆         ┆         ┆         ┆ g       ┆ /liches ┆         │
# │         ┆ B5/2P4P ┆ g3g2    ┆        ┆         ┆         ┆         ┆ endgame ┆ s.org/E ┆         │
# │         ┆ /4Pnp1/ ┆ e3e4    ┆        ┆         ┆         ┆         ┆ hanging ┆ pr0AiEh ┆         │
# │         ┆ Rb…     ┆ f3d4    ┆        ┆         ┆         ┆         ┆ Piece … ┆ /b…     ┆         │
# │         ┆         ┆ e2f2    ┆        ┆         ┆         ┆         ┆         ┆         ┆         │
# │ 001cr   ┆ 8/3B2pp ┆ c5c4    ┆ 1601   ┆ 82      ┆ 93      ┆ 2297    ┆ bishopE ┆ https:/ ┆ null    │
# │         ┆ /p5k1/2 ┆ d7e8    ┆        ┆         ┆         ┆         ┆ ndgame  ┆ /liches ┆         │
# │         ┆ p3P1/1p ┆         ┆        ┆         ┆         ┆         ┆ endgame ┆ s.org/7 ┆         │
# │         ┆ 1p1K2/8 ┆         ┆        ┆         ┆         ┆         ┆ mate    ┆ FFNwibw ┆         │
# │         ┆ /1…     ┆         ┆        ┆         ┆         ┆         ┆ mat…    ┆ /b…     ┆         │
# │ 001gi   ┆ r6r/1pN ┆ c7a8    ┆ 820    ┆ 119     ┆ 69      ┆ 262     ┆ bodenMa ┆ https:/ ┆ Sicilia │
# │         ┆ k1ppp/2 ┆ a5c3    ┆        ┆         ┆         ┆         ┆ te hang ┆ /liches ┆ n_Defen │
# │         ┆ np4/b3p ┆         ┆        ┆         ┆         ┆         ┆ ingPiec ┆ s.org/1 ┆ se Sici │
# │         ┆ 3/4P1b1 ┆         ┆        ┆         ┆         ┆         ┆ e mate  ┆ sV2Hr22 ┆ lian_De │
# │         ┆ /N…     ┆         ┆        ┆         ┆         ┆         ┆ ma…     ┆ #3…     ┆ fe…     │
# │ 001h8   ┆ 2r3k1/2 ┆ c4e2    ┆ 1780   ┆ 76      ┆ 88      ┆ 619     ┆ crushin ┆ https:/ ┆ null    │
# │         ┆ r4p/4p1 ┆ h4h7    ┆        ┆         ┆         ┆         ┆ g defle ┆ /liches ┆         │
# │         ┆ p1/1p1q ┆ c7h7    ┆        ┆         ┆         ┆         ┆ ction   ┆ s.org/I ┆         │
# │         ┆ 1pP1/p1 ┆ c1c8    ┆        ┆         ┆         ┆         ┆ kingsid ┆ xCahP6X ┆         │
# │         ┆ bP…     ┆ g8g7    ┆        ┆         ┆         ┆         ┆ eAt…    ┆ /b…     ┆         │
# │         ┆         ┆ c8c7    ┆        ┆         ┆         ┆         ┆         ┆         ┆         │
# │ 001kG   ┆ rnbq3r/ ┆ e7c5    ┆ 1918   ┆ 75      ┆ 96      ┆ 643     ┆ advanta ┆ https:/ ┆ Sicilia │
# │         ┆ 1p2bkpp ┆ d1h5    ┆        ┆         ┆         ┆         ┆ ge      ┆ /liches ┆ n_Defen │
# │         ┆ /p4n2/8 ┆ f7g8    ┆        ┆         ┆         ┆         ┆ opening ┆ s.org/x ┆ se Sici │
# │         ┆ /2pNP3/ ┆ h5c5    ┆        ┆         ┆         ┆         ┆ pin     ┆ XAEaVto ┆ lian_De │
# │         ┆ 2N…     ┆         ┆        ┆         ┆         ┆         ┆ short   ┆ /b…     ┆ fe…     │
# │ 001m3   ┆ 7r/6k1/ ┆ e2e6    ┆ 1459   ┆ 76      ┆ 87      ┆ 278     ┆ advanta ┆ https:/ ┆ null    │
# │         ┆ 2b1pp2/ ┆ h8h1    ┆        ┆         ┆         ┆         ┆ ge      ┆ /liches ┆         │
# │         ┆ 8/P1N3p ┆ f1e2    ┆        ┆         ┆         ┆         ┆ endgame ┆ s.org/L ┆         │
# │         ┆ 1/5nP1/ ┆ h1a1    ┆        ┆         ┆         ┆         ┆ short   ┆ ELOz22f ┆         │
# │         ┆ 4R…     ┆         ┆        ┆         ┆         ┆         ┆ skewer  ┆ #7…     ┆         │
# │ 001om   ┆ 5r1k/pp ┆ g4h4    ┆ 1018   ┆ 80      ┆ 89      ┆ 226     ┆ mate    ┆ https:/ ┆ null    │
# │         ┆ 4pp/5p2 ┆ c5f2    ┆        ┆         ┆         ┆         ┆ mateIn2 ┆ /liches ┆         │
# │         ┆ /1BbQp1 ┆ g2g3    ┆        ┆         ┆         ┆         ┆ middleg ┆ s.org/V ┆         │
# │         ┆ r1/6K1/ ┆ f2g3    ┆        ┆         ┆         ┆         ┆ ame     ┆ WOIWtIh ┆         │
# │         ┆ 7P…     ┆         ┆        ┆         ┆         ┆         ┆ morphy… ┆ #5…     ┆         │
# │ 001pC   ┆ r4rk1/p ┆ f1g1    ┆ 876    ┆ 75      ┆ 91      ┆ 430     ┆ mate    ┆ https:/ ┆ Sicilia │
# │         ┆ p3ppp/3 ┆ h3f2    ┆        ┆         ┆         ┆         ┆ mateIn1 ┆ /liches ┆ n_Defen │
# │         ┆ b4/2p1p ┆         ┆        ┆         ┆         ┆         ┆ middleg ┆ s.org/d ┆ se Sici │
# │         ┆ PB1/7N/ ┆         ┆        ┆         ┆         ┆         ┆ ame     ┆ 04UP3XD ┆ lian_De │
# │         ┆ 2P…     ┆         ┆        ┆         ┆         ┆         ┆ oneMov… ┆ #3…     ┆ fe…     │
# │ 001u3   ┆ 2r3k1/p ┆ c7b6    ┆ 2190   ┆ 80      ┆ 55      ┆ 82      ┆ advanta ┆ https:/ ┆ null    │
# │         ┆ 1q2pp1/ ┆ a6c8    ┆        ┆         ┆         ┆         ┆ ge hang ┆ /liches ┆         │
# │         ┆ Q3p2p/b ┆ g8h7    ┆        ┆         ┆         ┆         ┆ ingPiec ┆ s.org/B ┆         │
# │         ┆ 1Np4/2n ┆ c8b7    ┆        ┆         ┆         ┆         ┆ e middl ┆ Bn6ipaK ┆         │
# │         ┆ P1…     ┆         ┆        ┆         ┆         ┆         ┆ eg…     ┆ /b…     ┆         │
# │ 001uD   ┆ 6k1/1p3 ┆ f7f6    ┆ 1835   ┆ 76      ┆ 92      ┆ 960     ┆ advanta ┆ https:/ ┆ null    │
# │         ┆ pp1/1p5 ┆ f3d2    ┆        ┆         ┆         ┆         ┆ ge long ┆ /liches ┆         │
# │         ┆ p/2r1p3 ┆ c4d2    ┆        ┆         ┆         ┆         ┆ middleg ┆ s.org/2 ┆         │
# │         ┆ /2n5/r3 ┆ c2d2    ┆        ┆         ┆         ┆         ┆ ame     ┆ qkVLUl6 ┆         │
# │         ┆ PN…     ┆ c5c1    ┆        ┆         ┆         ┆         ┆         ┆ /b…     ┆         │
# │         ┆         ┆ e2c1    ┆        ┆         ┆         ┆         ┆         ┆         ┆         │
# │ 001w5   ┆ 1rb2rk1 ┆ f8f7    ┆ 1039   ┆ 80      ┆ 85      ┆ 212     ┆ advance ┆ https:/ ┆ null    │
# │         ┆ /q5P1/4 ┆ c2h7    ┆        ┆         ┆         ┆         ┆ dPawn   ┆ /liches ┆         │
# │         ┆ p2p/3p3 ┆ g8h7    ┆        ┆         ┆         ┆         ┆ attract ┆ s.org/0 ┆         │
# │         ┆ p/3P1P2 ┆ g7g8q   ┆        ┆         ┆         ┆         ┆ ion     ┆ e1vxAEn ┆         │
# │         ┆ /2…     ┆         ┆        ┆         ┆         ┆         ┆ mate m… ┆ /b…     ┆         │
# │ 001wR   ┆ 6nr/pp3 ┆ b7b5    ┆ 1186   ┆ 80      ┆ 93      ┆ 2605    ┆ endgame ┆ https:/ ┆ null    │
# │         ┆ p1p/k1p ┆ b4a5    ┆        ┆         ┆         ┆         ┆ long    ┆ /liches ┆         │
# │         ┆ 5/8/1QN ┆ a6b7    ┆        ┆         ┆         ┆         ┆ mate    ┆ s.org/r ┆         │
# │         ┆ 5/2P1P3 ┆ c4d6    ┆        ┆         ┆         ┆         ┆ mateIn3 ┆ uvbd9JW ┆         │
# │         ┆ /4…     ┆ b7b8    ┆        ┆         ┆         ┆         ┆         ┆ /b…     ┆         │
# │         ┆         ┆ a5d8    ┆        ┆         ┆         ┆         ┆         ┆         ┆         │
# │ 001wb   ┆ r3k2r/p ┆ h2g3    ┆ 1207   ┆ 76      ┆ 94      ┆ 212     ┆ mate    ┆ https:/ ┆ Ruy_Lop │
# │         ┆ b1p1ppp ┆ g6h5    ┆        ┆         ┆         ┆         ┆ mateIn1 ┆ /liches ┆ ez Ruy_ │
# │         ┆ /1b4q1/ ┆         ┆        ┆         ┆         ┆         ┆ middleg ┆ s.org/h ┆ Lopez_B │
# │         ┆ 1Q2P3/8 ┆         ┆        ┆         ┆         ┆         ┆ ame     ┆ NzYRMWP ┆ ird_Var │
# │         ┆ /2…     ┆         ┆        ┆         ┆         ┆         ┆ oneMov… ┆ #3…     ┆ ia…     │
# │ 001wr   ┆ r4rk1/p ┆ f2f3    ┆ 946    ┆ 82      ┆ 97      ┆ 2330    ┆ advanta ┆ https:/ ┆ Pirc_De │
# │         ┆ 3ppbp/P ┆ d6c5    ┆        ┆         ┆         ┆         ┆ ge fork ┆ /liches ┆ fense   │
# │         ┆ p1q1np1 ┆ g1h1    ┆        ┆         ┆         ┆         ┆ master  ┆ s.org/K ┆ Pirc_De │
# │         ┆ /3PpbB1 ┆ c5c4    ┆        ┆         ┆         ┆         ┆ masterV ┆ nJ2mojX ┆ fense_C │
# │         ┆ /2…     ┆         ┆        ┆         ┆         ┆         ┆ s…      ┆ #3…     ┆ las…    │
# │ 001xO   ┆ k1r1b3/ ┆ d3a6    ┆ 1710   ┆ 74      ┆ 91      ┆ 1335    ┆ crushin ┆ https:/ ┆ Slav_De │
# │         ┆ p1r1npp ┆ b6c5    ┆        ┆         ┆         ┆         ┆ g       ┆ /liches ┆ fense   │
# │         ┆ p/1p1qp ┆ a6c8    ┆        ┆         ┆         ┆         ┆ master  ┆ s.org/f ┆ Slav_De │
# │         ┆ n2/2Np4 ┆ c5c4    ┆        ┆         ┆         ┆         ┆ masterV ┆ NCePFgY ┆ fense_O │
# │         ┆ /1…     ┆         ┆        ┆         ┆         ┆         ┆ sMaster ┆ #3…     ┆ the…    │
# │         ┆         ┆         ┆        ┆         ┆         ┆         ┆ …       ┆         ┆         │
# │ 001xl   ┆ 8/4R1k1 ┆ g7f6    ┆ 1126   ┆ 81      ┆ 94      ┆ 11642   ┆ advanta ┆ https:/ ┆ null    │
# │         ┆ /p5pp/3 ┆ e7f7    ┆        ┆         ┆         ┆         ┆ ge      ┆ /liches ┆         │
# │         ┆ B4/5q2/ ┆ f6e5    ┆        ┆         ┆         ┆         ┆ endgame ┆ s.org/b ┆         │
# │         ┆ 8/5P1P/ ┆ f7f4    ┆        ┆         ┆         ┆         ┆ master  ┆ EQkfPQD ┆         │
# │         ┆ 6K…     ┆         ┆        ┆         ┆         ┆         ┆ maste…  ┆ /b…     ┆         │
# │ 002CP   ┆ r5k1/pp ┆ f2e3    ┆ 925    ┆ 84      ┆ 69      ┆ 89      ┆ endgame ┆ https:/ ┆ null    │
# │         ┆ 4pp/4p1 ┆ g6c2    ┆        ┆         ┆         ┆         ┆ mate    ┆ /liches ┆         │
# │         ┆ q1/4p3/ ┆         ┆        ┆         ┆         ┆         ┆ mateIn1 ┆ s.org/p ┆         │
# │         ┆ 3n4/P5P ┆         ┆        ┆         ┆         ┆         ┆ oneMove ┆ HZnIFdb ┆         │
# │         ┆ 1/…     ┆         ┆        ┆         ┆         ┆         ┆ q…      ┆ #4…     ┆         │
# │ 002Ds   ┆ 8/1pp5/ ┆ b7b6    ┆ 1992   ┆ 76      ┆ 90      ┆ 113     ┆ crushin ┆ https:/ ┆ null    │
# │         ┆ p2p4/P2 ┆ b4b5    ┆        ┆         ┆         ┆         ┆ g       ┆ /liches ┆         │
# │         ┆ Pk2p/1P ┆ c3d1    ┆        ┆         ┆         ┆         ┆ endgame ┆ s.org/2 ┆         │
# │         ┆ P1p2P/2 ┆ e3e2    ┆        ┆         ┆         ┆         ┆ knightE ┆ SrvOtZN ┆         │
# │         ┆ n1…     ┆ a6b5    ┆        ┆         ┆         ┆         ┆ ndgame… ┆ /b…     ┆         │
# │         ┆         ┆ a5a6    ┆        ┆         ┆         ┆         ┆         ┆         ┆         │
# │ 002GQ   ┆ 5rk1/5p ┆ f1c1    ┆ 654    ┆ 81      ┆ 73      ┆ 134     ┆ crushin ┆ https:/ ┆ null    │
# │         ┆ pp/4p3/ ┆ c3e2    ┆        ┆         ┆         ┆         ┆ g       ┆ /liches ┆         │
# │         ┆ 4N3/8/1 ┆ g1f1    ┆        ┆         ┆         ┆         ┆ endgame ┆ s.org/2 ┆         │
# │         ┆ Pn5/5PP ┆ e2c1    ┆        ┆         ┆         ┆         ┆ fork    ┆ K7g2pDT ┆         │
# │         ┆ P/…     ┆         ┆        ┆         ┆         ┆         ┆ short   ┆ #5…     ┆         │
# │ 002HE   ┆ 1qr2rk1 ┆ g1f2    ┆ 1063   ┆ 76      ┆ 100     ┆ 461     ┆ master  ┆ https:/ ┆ null    │
# │         ┆ /1p1p1p ┆ b8g3    ┆        ┆         ┆         ┆         ┆ mate    ┆ /liches ┆         │
# │         ┆ pp/pB2p ┆         ┆        ┆         ┆         ┆         ┆ mateIn1 ┆ s.org/U ┆         │
# │         ┆ 1n1/7n/ ┆         ┆        ┆         ┆         ┆         ┆ middleg ┆ 21EXYdv ┆         │
# │         ┆ 2P…     ┆         ┆        ┆         ┆         ┆         ┆ ame…    ┆ #3…     ┆         │
# │ 002Hv   ┆ 8/8/8/3 ┆ d5f4    ┆ 1621   ┆ 86      ┆ 63      ┆ 26      ┆ advance ┆ https:/ ┆ null    │
# │         ┆ N2p1/5b ┆ g5f4    ┆        ┆         ┆         ┆         ┆ dPawn   ┆ /liches ┆         │
# │         ┆ 2/3p3P/ ┆ h3h4    ┆        ┆         ┆         ┆         ┆ crushin ┆ s.org/r ┆         │
# │         ┆ 5kP1/3K ┆ f2g2    ┆        ┆         ┆         ┆         ┆ g       ┆ LJ8Hp1v ┆         │
# │         ┆ 4 …     ┆ h4h5    ┆        ┆         ┆         ┆         ┆ endgame ┆ #1…     ┆         │
# │         ┆         ┆ f4f3 …  ┆        ┆         ┆         ┆         ┆ …       ┆         ┆         │
# │ …       ┆ …       ┆ …       ┆ …      ┆ …       ┆ …       ┆ …       ┆ …       ┆ …       ┆ …       │
# │ zzyIA   ┆ 6k1/4rp ┆ c2g2    ┆ 825    ┆ 83      ┆ 94      ┆ 71      ┆ kingsid ┆ https:/ ┆ null    │
# │         ┆ p1/2Bp3 ┆ h4e1    ┆        ┆         ┆         ┆         ┆ eAttack ┆ /liches ┆         │
# │         ┆ p/p7/P1 ┆ g2f1    ┆        ┆         ┆         ┆         ┆ mate    ┆ s.org/3 ┆         │
# │         ┆ P1Pp1q/ ┆ e1f1    ┆        ┆         ┆         ┆         ┆ mateIn2 ┆ kt9sX2R ┆         │
# │         ┆ 2P…     ┆         ┆        ┆         ┆         ┆         ┆ mi…     ┆ #7…     ┆         │
# │ zzyNM   ┆ 8/8/3k4 ┆ b4b5    ┆ 2517   ┆ 92      ┆ 90      ┆ 1058    ┆ advance ┆ https:/ ┆ null    │
# │         ┆ /3pR3/1 ┆ e4e3    ┆        ┆         ┆         ┆         ┆ dPawn   ┆ /liches ┆         │
# │         ┆ K1Pp3/2 ┆ c3c4    ┆        ┆         ┆         ┆         ┆ crushin ┆ s.org/m ┆         │
# │         ┆ P5/8/4r ┆ e3e2    ┆        ┆         ┆         ┆         ┆ g defen ┆ 6yIUDrj ┆         │
# │         ┆ 3 …     ┆ e5d5    ┆        ┆         ┆         ┆         ┆ siv…    ┆ #8…     ┆         │
# │         ┆         ┆ d6c7    ┆        ┆         ┆         ┆         ┆         ┆         ┆         │
# │ zzyOe   ┆ 8/P1n5/ ┆ g5g4    ┆ 2158   ┆ 77      ┆ 90      ┆ 790     ┆ advanta ┆ https:/ ┆ null    │
# │         ┆ 4p3/6k1 ┆ f3g1    ┆        ┆         ┆         ┆         ┆ ge defe ┆ /liches ┆         │
# │         ┆ /1P3p2/ ┆ f4f3    ┆        ┆         ┆         ┆         ┆ nsiveMo ┆ s.org/U ┆         │
# │         ┆ 1P3N2/1 ┆ g1f3    ┆        ┆         ┆         ┆         ┆ ve      ┆ EY5bWOD ┆         │
# │         ┆ K6…     ┆ g4f3    ┆        ┆         ┆         ┆         ┆ endgam… ┆ /b…     ┆         │
# │         ┆         ┆ b4b5 …  ┆        ┆         ┆         ┆         ┆         ┆         ┆         │
# │ zzyU9   ┆ 7k/7p/p ┆ e6f6    ┆ 638    ┆ 95      ┆ 88      ┆ 277     ┆ endgame ┆ https:/ ┆ null    │
# │         ┆ 3rNpP/1 ┆ c1c8    ┆        ┆         ┆         ┆         ┆ mate    ┆ /liches ┆         │
# │         ┆ p2ppP1/ ┆ f6f8    ┆        ┆         ┆         ┆         ┆ mateIn2 ┆ s.org/s ┆         │
# │         ┆ 1r1p4/3 ┆ c8f8    ┆        ┆         ┆         ┆         ┆ rookEnd ┆ FWYlJNg ┆         │
# │         ┆ P1…     ┆         ┆        ┆         ┆         ┆         ┆ ga…     ┆ /b…     ┆         │
# │ zzyUV   ┆ 8/p5pp/ ┆ e2d3    ┆ 2543   ┆ 121     ┆ 85      ┆ 26      ┆ crushin ┆ https:/ ┆ null    │
# │         ┆ 1p4k1/2 ┆ c2d3    ┆        ┆         ┆         ┆         ┆ g       ┆ /liches ┆         │
# │         ┆ p5/2K4P ┆ g6f5    ┆        ┆         ┆         ┆         ┆ endgame ┆ s.org/J ┆         │
# │         ┆ /1P1N2P ┆ c4b5    ┆        ┆         ┆         ┆         ┆ long    ┆ wfmEg5T ┆         │
# │         ┆ 1/…     ┆ g7g5    ┆        ┆         ┆         ┆         ┆         ┆ /b…     ┆         │
# │         ┆         ┆ b5a6    ┆        ┆         ┆         ┆         ┆         ┆         ┆         │
# │ zzya7   ┆ 4rk2/pp ┆ f2f4    ┆ 1691   ┆ 74      ┆ 88      ┆ 974     ┆ advanta ┆ https:/ ┆ null    │
# │         ┆ p3p1/2b ┆ e5d4    ┆        ┆         ┆         ┆         ┆ ge midd ┆ /liches ┆         │
# │         ┆ pqp2/4b ┆ g1f1    ┆        ┆         ┆         ┆         ┆ legame  ┆ s.org/2 ┆         │
# │         ┆ 2Q/8/2N ┆ e6c4    ┆        ┆         ┆         ┆         ┆ short   ┆ yA2jTei ┆         │
# │         ┆ 5/…     ┆         ┆        ┆         ┆         ┆         ┆         ┆ #3…     ┆         │
# │ zzycE   ┆ 1r4k1/p ┆ b2a3    ┆ 1153   ┆ 77      ┆ 100     ┆ 608     ┆ endgame ┆ https:/ ┆ null    │
# │         ┆ 1R2p1p/ ┆ h1c1    ┆        ┆         ┆         ┆         ┆ mate    ┆ /liches ┆         │
# │         ┆ 2b3pP/4 ┆ c3b2    ┆        ┆         ┆         ┆         ┆ mateIn2 ┆ s.org/O ┆         │
# │         ┆ B3/3P2P ┆ c1b2    ┆        ┆         ┆         ┆         ┆ short   ┆ kWNe9Mf ┆         │
# │         ┆ 1/…     ┆         ┆        ┆         ┆         ┆         ┆         ┆ #6…     ┆         │
# │ zzycH   ┆ 6k1/6p1 ┆ c1c2    ┆ 927    ┆ 96      ┆ 87      ┆ 297     ┆ crushin ┆ https:/ ┆ null    │
# │         ┆ /7p/3pP ┆ b2c2    ┆        ┆         ┆         ┆         ┆ g       ┆ /liches ┆         │
# │         ┆ p2/3P4/ ┆ b3c2    ┆        ┆         ┆         ┆         ┆ endgame ┆ s.org/3 ┆         │
# │         ┆ 1p6/1R2 ┆ e2d2    ┆        ┆         ┆         ┆         ┆ rookEnd ┆ 4wjTHxO ┆         │
# │         ┆ KP…     ┆         ┆        ┆         ┆         ┆         ┆ game s… ┆ /b…     ┆         │
# │ zzyeq   ┆ 1r3k1r/ ┆ e2d3    ┆ 2191   ┆ 80      ┆ 85      ┆ 196     ┆ advanta ┆ https:/ ┆ null    │
# │         ┆ ppp2p1p ┆ g4e6    ┆        ┆         ┆         ┆         ┆ ge      ┆ /liches ┆         │
# │         ┆ /5R2/4p ┆ d3g6    ┆        ┆         ┆         ┆         ┆ endgame ┆ s.org/W ┆         │
# │         ┆ 3/P5Q1/ ┆ e6e5    ┆        ┆         ┆         ┆         ┆ pin ver ┆ lqQV9xM ┆         │
# │         ┆ 3P…     ┆ b8e8    ┆        ┆         ┆         ┆         ┆ yLong   ┆ /b…     ┆         │
# │         ┆         ┆ e5c5 …  ┆        ┆         ┆         ┆         ┆         ┆         ┆         │
# │ zzyfI   ┆ Qnk4r/1 ┆ h8e8    ┆ 1680   ┆ 74      ┆ 95      ┆ 2374    ┆ advanta ┆ https:/ ┆ null    │
# │         ┆ pp2p2/2 ┆ a8b8    ┆        ┆         ┆         ┆         ┆ ge midd ┆ /liches ┆         │
# │         ┆ q4p/3pr ┆ c8d7    ┆        ┆         ┆         ┆         ┆ legame  ┆ s.org/c ┆         │
# │         ┆ 1p1/R7/ ┆ b8a7    ┆        ┆         ┆         ┆         ┆ queensi ┆ yHVtVXr ┆         │
# │         ┆ 1P…     ┆         ┆        ┆         ┆         ┆         ┆ de…     ┆ /b…     ┆         │
# │ zzyfU   ┆ 6r1/pQ3 ┆ d6e7    ┆ 1269   ┆ 76      ┆ 88      ┆ 617     ┆ advanta ┆ https:/ ┆ null    │
# │         ┆ kp1/3q3 ┆ g2g7    ┆        ┆         ┆         ┆         ┆ ge attr ┆ /liches ┆         │
# │         ┆ r/p1p1p ┆ g8g7    ┆        ┆         ┆         ┆         ┆ action  ┆ s.org/k ┆         │
# │         ┆ 3/5p2/1 ┆ g1g7    ┆        ┆         ┆         ┆         ┆ endgame ┆ MygdOr3 ┆         │
# │         ┆ P3…     ┆ f7g7    ┆        ┆         ┆         ┆         ┆ l…      ┆ /b…     ┆         │
# │         ┆         ┆ b7e7    ┆        ┆         ┆         ┆         ┆         ┆         ┆         │
# │ zzyhn   ┆ 2r3k1/5 ┆ b1h1    ┆ 931    ┆ 84      ┆ 41      ┆ 43      ┆ crushin ┆ https:/ ┆ null    │
# │         ┆ p2/3B2p ┆ h2h1    ┆        ┆         ┆         ┆         ┆ g       ┆ /liches ┆         │
# │         ┆ 1/p3Pb2 ┆ c3d2    ┆        ┆         ┆         ┆         ┆ endgame ┆ s.org/3 ┆         │
# │         ┆ /6P1/2p ┆ e3d2    ┆        ┆         ┆         ┆         ┆ short   ┆ bjpGGWi ┆         │
# │         ┆ 1Q…     ┆         ┆        ┆         ┆         ┆         ┆         ┆ /b…     ┆         │
# │ zzyir   ┆ r4rk1/p ┆ c4d5    ┆ 868    ┆ 78      ┆ 100     ┆ 225     ┆ kingsid ┆ https:/ ┆ Dutch_D │
# │         ┆ 1qpn1pp ┆ c7h2    ┆        ┆         ┆         ┆         ┆ eAttack ┆ /liches ┆ efense  │
# │         ┆ /1p2p3/ ┆         ┆        ┆         ┆         ┆         ┆ mate    ┆ s.org/y ┆ Dutch_D │
# │         ┆ 3p1p2/2 ┆         ┆        ┆         ┆         ┆         ┆ mateIn1 ┆ 99FXTFh ┆ efense_ │
# │         ┆ PP…     ┆         ┆        ┆         ┆         ┆         ┆ mi…     ┆ #2…     ┆ Ot…     │
# │ zzymq   ┆ 3R4/3P4 ┆ d6d7    ┆ 2282   ┆ 82      ┆ 91      ┆ 107     ┆ crushin ┆ https:/ ┆ null    │
# │         ┆ /3r1p2/ ┆ d8d7    ┆        ┆         ┆         ┆         ┆ g       ┆ /liches ┆         │
# │         ┆ 5K2/8/5 ┆ h1g2    ┆        ┆         ┆         ┆         ┆ endgame ┆ s.org/2 ┆         │
# │         ┆ P2/7p/7 ┆ d7h7    ┆        ┆         ┆         ┆         ┆ hanging ┆ EWZsxmh ┆         │
# │         ┆ k …     ┆ g2f3    ┆        ┆         ┆         ┆         ┆ Piece … ┆ /b…     ┆         │
# │         ┆         ┆ h7h2    ┆        ┆         ┆         ┆         ┆         ┆         ┆         │
# │ zzynX   ┆ 8/R7/3p ┆ h6h7    ┆ 2752   ┆ 91      ┆ 82      ┆ 81      ┆ advance ┆ https:/ ┆ null    │
# │         ┆ 1p1P/1r ┆ b5b8    ┆        ┆         ┆         ┆         ┆ dPawn   ┆ /liches ┆         │
# │         ┆ 1P2p1/4 ┆ e4e5    ┆        ┆         ┆         ┆         ┆ advanta ┆ s.org/J ┆         │
# │         ┆ P1P1/5P ┆ f6e5    ┆        ┆         ┆         ┆         ┆ ge defl ┆ 4v2QUQT ┆         │
# │         ┆ 2/…     ┆ f3f4    ┆        ┆         ┆         ┆         ┆ ect…    ┆ #1…     ┆         │
# │         ┆         ┆ b8h8 …  ┆        ┆         ┆         ┆         ┆         ┆         ┆         │
# │ zzynZ   ┆ 8/8/5kp ┆ f6e6    ┆ 2311   ┆ 77      ┆ 93      ┆ 777     ┆ crushin ┆ https:/ ┆ null    │
# │         ┆ 1/5p2/5 ┆ f4g5    ┆        ┆         ┆         ┆         ┆ g defle ┆ /liches ┆         │
# │         ┆ K1P/8/6 ┆ e6f7    ┆        ┆         ┆         ┆         ┆ ction   ┆ s.org/x ┆         │
# │         ┆ P1/8 b  ┆ h4h5    ┆        ┆         ┆         ┆         ┆ endgame ┆ fxvFDZO ┆         │
# │         ┆ - …     ┆ g6h5    ┆        ┆         ┆         ┆         ┆ pa…     ┆ /b…     ┆         │
# │         ┆         ┆ g5f5 …  ┆        ┆         ┆         ┆         ┆         ┆         ┆         │
# │ zzyqh   ┆ 8/7r/6k ┆ g6h6    ┆ 1633   ┆ 74      ┆ 98      ┆ 1682    ┆ crushin ┆ https:/ ┆ null    │
# │         ┆ 1/4K3/8 ┆ e5f6    ┆        ┆         ┆         ┆         ┆ g       ┆ /liches ┆         │
# │         ┆ /8/8/6R ┆ h6h5    ┆        ┆         ┆         ┆         ┆ endgame ┆ s.org/c ┆         │
# │         ┆ 1 b - - ┆ g1h1    ┆        ┆         ┆         ┆         ┆ exposed ┆ bVNvYPu ┆         │
# │         ┆ 1…      ┆ h5g4    ┆        ┆         ┆         ┆         ┆ King l… ┆ /b…     ┆         │
# │         ┆         ┆ h1h7    ┆        ┆         ┆         ┆         ┆         ┆         ┆         │
# │ zzyrN   ┆ 8/8/1N6 ┆ d3e3    ┆ 1557   ┆ 75      ┆ 97      ┆ 16365   ┆ advance ┆ https:/ ┆ null    │
# │         ┆ /3p1k2/ ┆ b4b3    ┆        ┆         ┆         ┆         ┆ dPawn   ┆ /liches ┆         │
# │         ┆ 1p1P1P2 ┆ e3d2    ┆        ┆         ┆         ┆         ┆ crushin ┆ s.org/j ┆         │
# │         ┆ /2nK4/8 ┆ b3b2    ┆        ┆         ┆         ┆         ┆ g       ┆ b7LZBGO ┆         │
# │         ┆ /8…     ┆ b6d5    ┆        ┆         ┆         ┆         ┆ endgame ┆ #9…     ┆         │
# │         ┆         ┆ b2b1q   ┆        ┆         ┆         ┆         ┆ …       ┆         ┆         │
# │ zzytn   ┆ r1q3r1/ ┆ f6f5    ┆ 844    ┆ 80      ┆ 100     ┆ 132     ┆ mate    ┆ https:/ ┆ English │
# │         ┆ ppbb1pk ┆ d2h6    ┆        ┆         ┆         ┆         ┆ mateIn1 ┆ /liches ┆ _Openin │
# │         ┆ 1/2pp1p ┆         ┆        ┆         ┆         ┆         ┆ middleg ┆ s.org/x ┆ g Engli │
# │         ┆ np/4p3/ ┆         ┆        ┆         ┆         ┆         ┆ ame     ┆ uefEUkq ┆ sh_Open │
# │         ┆ 1P…     ┆         ┆        ┆         ┆         ┆         ┆ oneMov… ┆ /b…     ┆ in…     │
# │ zzywJ   ┆ 4rrk1/p ┆ e4e8    ┆ 1453   ┆ 75      ┆ 94      ┆ 1234    ┆ advanta ┆ https:/ ┆ null    │
# │         ┆ 1q3p1/1 ┆ f5g4    ┆        ┆         ┆         ┆         ┆ ge      ┆ /liches ┆         │
# │         ┆ p5p/2p2 ┆ e8f8    ┆        ┆         ┆         ┆         ┆ endgame ┆ s.org/O ┆         │
# │         ┆ p2/4R1Q ┆ g8f8    ┆        ┆         ┆         ┆         ┆ short   ┆ NII3ByI ┆         │
# │         ┆ 1/…     ┆         ┆        ┆         ┆         ┆         ┆         ┆ #4…     ┆         │
# │ zzywX   ┆ 6k1/6pp ┆ g1f1    ┆ 1015   ┆ 95      ┆ 95      ┆ 612     ┆ blindSw ┆ https:/ ┆ null    │
# │         ┆ /1p6/p2 ┆ b2f2    ┆        ┆         ┆         ┆         ┆ ineMate ┆ /liches ┆         │
# │         ┆ N4/P2N4 ┆         ┆        ┆         ┆         ┆         ┆ endgame ┆ s.org/6 ┆         │
# │         ┆ /1P6/1r ┆         ┆        ┆         ┆         ┆         ┆ mate    ┆ IuuJRUv ┆         │
# │         ┆ 4r…     ┆         ┆        ┆         ┆         ┆         ┆ ma…     ┆ #6…     ┆         │
# │ zzywe   ┆ B3kbnr/ ┆ c2c4    ┆ 1418   ┆ 88      ┆ 83      ┆ 4471    ┆ mate    ┆ https:/ ┆ null    │
# │         ┆ p1p2ppp ┆ d4f3    ┆        ┆         ┆         ┆         ┆ mateIn1 ┆ /liches ┆         │
# │         ┆ /8/3pp3 ┆         ┆        ┆         ┆         ┆         ┆ middleg ┆ s.org/h ┆         │
# │         ┆ /3nq3/8 ┆         ┆        ┆         ┆         ┆         ┆ ame     ┆ 2ObbOBC ┆         │
# │         ┆ /P…     ┆         ┆        ┆         ┆         ┆         ┆ oneMov… ┆ #1…     ┆         │
# │ zzyxB   ┆ r6k/4qp ┆ e4f3    ┆ 1621   ┆ 76      ┆ 83      ┆ 175     ┆ attract ┆ https:/ ┆ null    │
# │         ┆ 1P/2p1p ┆ a2d2    ┆        ┆         ┆         ┆         ┆ ion cru ┆ /liches ┆         │
# │         ┆ 1p1/2Pn ┆ f2d2    ┆        ┆         ┆         ┆         ┆ shing   ┆ s.org/f ┆         │
# │         ┆ P3/1p1P ┆ e7g5    ┆        ┆         ┆         ┆         ┆ fork    ┆ gAJcTzX ┆         │
# │         ┆ Q3…     ┆ h3g3    ┆        ┆         ┆         ┆         ┆ long …  ┆ #7…     ┆         │
# │         ┆         ┆ g5d2    ┆        ┆         ┆         ┆         ┆         ┆         ┆         │
# │ zzz1y   ┆ 6R1/8/8 ┆ g8g7    ┆ 2297   ┆ 87      ┆ 90      ┆ 1043    ┆ crushin ┆ https:/ ┆ null    │
# │         ┆ /5p2/3P ┆ a1f1    ┆        ┆         ┆         ┆         ┆ g defen ┆ /liches ┆         │
# │         ┆ 1P2/5K2 ┆ f3e3    ┆        ┆         ┆         ┆         ┆ siveMov ┆ s.org/W ┆         │
# │         ┆ /7p/r6k ┆ f1g1    ┆        ┆         ┆         ┆         ┆ e endga ┆ LceSm9N ┆         │
# │         ┆ w…      ┆ g7h7    ┆        ┆         ┆         ┆         ┆ me…     ┆ #9…     ┆         │
# │         ┆         ┆ h1g2    ┆        ┆         ┆         ┆         ┆         ┆         ┆         │
# │ zzz2O   ┆ 3r1rk1/ ┆ c3e5    ┆ 1986   ┆ 78      ┆ 90      ┆ 54      ┆ crushin ┆ https:/ ┆ null    │
# │         ┆ 6b1/3R2 ┆ d8d6    ┆        ┆         ┆         ┆         ┆ g fork  ┆ /liches ┆         │
# │         ┆ p1/1p2p ┆ e5g7    ┆        ┆         ┆         ┆         ┆ long    ┆ s.org/U ┆         │
# │         ┆ 2p/1P5P ┆ f3f2    ┆        ┆         ┆         ┆         ┆ middleg ┆ BigL4Vc ┆         │
# │         ┆ /2…     ┆ b2f2    ┆        ┆         ┆         ┆         ┆ ame     ┆ #5…     ┆         │
# │         ┆         ┆ f8f2    ┆        ┆         ┆         ┆         ┆         ┆         ┆         │
# │ zzz5v   ┆ 8/3Q2k1 ┆ g7g6    ┆ 1261   ┆ 75      ┆ 97      ┆ 3119    ┆ advance ┆ https:/ ┆ null    │
# │         ┆ /3P1p1p ┆ d7e8    ┆        ┆         ┆         ┆         ┆ dPawn   ┆ /liches ┆         │
# │         ┆ /6pq/5n ┆ g6g7    ┆        ┆         ┆         ┆         ┆ crushin ┆ s.org/5 ┆         │
# │         ┆ 2/2P2P1 ┆ e8h5    ┆        ┆         ┆         ┆         ┆ g defle ┆ BUDTpuB ┆         │
# │         ┆ P/…     ┆ f4h5    ┆        ┆         ┆         ┆         ┆ cti…    ┆ /b…     ┆         │
# │         ┆         ┆ d6d7    ┆        ┆         ┆         ┆         ┆         ┆         ┆         │
# │ zzz6W   ┆ 1bkr4/p ┆ d8h8    ┆ 2082   ┆ 76      ┆ 89      ┆ 1177    ┆ crushin ┆ https:/ ┆ null    │
# │         ┆ 6R/Pp4p ┆ e3f4    ┆        ┆         ┆         ┆         ┆ g defle ┆ /liches ┆         │
# │         ┆ 1/1Np1q ┆ e5f4    ┆        ┆         ┆         ┆         ┆ ction   ┆ s.org/j ┆         │
# │         ┆ 3/2P1p1 ┆ h7h8    ┆        ┆         ┆         ┆         ┆ middleg ┆ qOr59kg ┆         │
# │         ┆ P1…     ┆         ┆        ┆         ┆         ┆         ┆ ame…    ┆ /b…     ┆         │
# │ zzz6b   ┆ 4rrk1/R ┆ e4c3    ┆ 1619   ┆ 77      ┆ 84      ┆ 57      ┆ crushin ┆ https:/ ┆ Italian │
# │         ┆ pp2pp1/ ┆ e2e8    ┆        ┆         ┆         ┆         ┆ g kings ┆ /liches ┆ _Game   │
# │         ┆ 5q1p/3p ┆ f8e8    ┆        ┆         ┆         ┆         ┆ ideAtta ┆ s.org/2 ┆ Italian │
# │         ┆ 4/4n3/1 ┆ e1e8    ┆        ┆         ┆         ┆         ┆ ck long ┆ d0uEKKG ┆ _Game_S │
# │         ┆ PP…     ┆ g8h7    ┆        ┆         ┆         ┆         ┆ m…      ┆ /b…     ┆ cot…    │
# │         ┆         ┆ b2c3    ┆        ┆         ┆         ┆         ┆         ┆         ┆         │
# │ zzz71   ┆ 3r2k1/2 ┆ f2e2    ┆ 1680   ┆ 75      ┆ 100     ┆ 308     ┆ endgame ┆ https:/ ┆ null    │
# │         ┆ p3p1/p5 ┆ d8d2    ┆        ┆         ┆         ┆         ┆ mate    ┆ /liches ┆         │
# │         ┆ Q1/1p6/ ┆ e2e1    ┆        ┆         ┆         ┆         ┆ mateIn2 ┆ s.org/V ┆         │
# │         ┆ 5q2/2P4 ┆ f4e3    ┆        ┆         ┆         ┆         ┆ short   ┆ Z6W8rwz ┆         │
# │         ┆ P/…     ┆         ┆        ┆         ┆         ┆         ┆         ┆ #6…     ┆         │
# │ zzz7H   ┆ 8/8/4p1 ┆ f5f4    ┆ 1337   ┆ 75      ┆ 98      ┆ 2982    ┆ crushin ┆ https:/ ┆ null    │
# │         ┆ kp/1p2P ┆ g3f4    ┆        ┆         ┆         ┆         ┆ g       ┆ /liches ┆         │
# │         ┆ p2/1Pp3 ┆ g6f5    ┆        ┆         ┆         ┆         ┆ endgame ┆ s.org/r ┆         │
# │         ┆ pP/2P3P ┆ g2g3    ┆        ┆         ┆         ┆         ┆ long    ┆ o5lggqr ┆         │
# │         ┆ 1/…     ┆ f5e4    ┆        ┆         ┆         ┆         ┆ pawnEnd ┆ /b…     ┆         │
# │         ┆         ┆ g3g4    ┆        ┆         ┆         ┆         ┆ g…      ┆         ┆         │
# │ zzzAA   ┆ r4rk1/5 ┆ c5d5    ┆ 1952   ┆ 77      ┆ 78      ┆ 58      ┆ advanta ┆ https:/ ┆ null    │
# │         ┆ Rbp/2p3 ┆ f7f8    ┆        ┆         ┆         ┆         ┆ ge fork ┆ /liches ┆         │
# │         ┆ p1/p1q5 ┆ a8f8    ┆        ┆         ┆         ┆         ┆ middleg ┆ s.org/H ┆         │
# │         ┆ /2p1N3/ ┆ f3f8    ┆        ┆         ┆         ┆         ┆ ame     ┆ 9Gr825S ┆         │
# │         ┆ P4…     ┆ g7f8    ┆        ┆         ┆         ┆         ┆ sacr…   ┆ /b…     ┆         │
# │         ┆         ┆ e4f6 …  ┆        ┆         ┆         ┆         ┆         ┆         ┆         │
# │ zzzBa   ┆ 8/p3qpp ┆ e6e2    ┆ 2082   ┆ 73      ┆ 94      ┆ 5749    ┆ advanta ┆ https:/ ┆ null    │
# │         ┆ k/1p2rn ┆ d2e3    ┆        ┆         ┆         ┆         ┆ ge      ┆ /liches ┆         │
# │         ┆ 1p/2p5/ ┆ e2e3    ┆        ┆         ┆         ┆         ┆ endgame ┆ s.org/9 ┆         │
# │         ┆ 3p4/PP1 ┆ f2e3    ┆        ┆         ┆         ┆         ┆ master  ┆ Q2St8kL ┆         │
# │         ┆ P1…     ┆         ┆        ┆         ┆         ┆         ┆ short…  ┆ /b…     ┆         │
# │ zzzGF   ┆ 2b2rk1/ ┆ a5a7    ┆ 1124   ┆ 77      ┆ 100     ┆ 145     ┆ backRan ┆ https:/ ┆ null    │
# │         ┆ 7p/2p3p ┆ b2f2    ┆        ┆         ┆         ┆         ┆ kMate   ┆ /liches ┆         │
# │         ┆ Q/R2p4/ ┆ g1h1    ┆        ┆         ┆         ┆         ┆ endgame ┆ s.org/O ┆         │
# │         ┆ 3Pp3/8/ ┆ f2f1    ┆        ┆         ┆         ┆         ┆ long    ┆ IYPoQX6 ┆         │
# │         ┆ 1q…     ┆ a1f1    ┆        ┆         ┆         ┆         ┆ mate…   ┆ #7…     ┆         │
# │         ┆         ┆ f8f1    ┆        ┆         ┆         ┆         ┆         ┆         ┆         │
# │ zzzJS   ┆ r3kb1r/ ┆ a5a2    ┆ 776    ┆ 87      ┆ 99      ┆ 1630    ┆ crushin ┆ https:/ ┆ Caro-Ka │
# │         ┆ 5ppp/p1 ┆ b5c7    ┆        ┆         ┆         ┆         ┆ g fork  ┆ /liches ┆ nn_Defe │
# │         ┆ n1p3/qN ┆ e8d7    ┆        ┆         ┆         ┆         ┆ middleg ┆ s.org/a ┆ nse Car │
# │         ┆ 1pP3/3P ┆ c7a8    ┆        ┆         ┆         ┆         ┆ ame     ┆ Bcnhoi2 ┆ o-Kann_ │
# │         ┆ 4/…     ┆         ┆        ┆         ┆         ┆         ┆ short   ┆ /b…     ┆ De…     │
# │ zzzKH   ┆ q6r/5kb ┆ d2c2    ┆ 1553   ┆ 76      ┆ 93      ┆ 2416    ┆ crushin ┆ https:/ ┆ null    │
# │         ┆ 1/p3pn1 ┆ c5d3    ┆        ┆         ┆         ┆         ┆ g fork  ┆ /liches ┆         │
# │         ┆ p/1pn4P ┆ c2d3    ┆        ┆         ┆         ┆         ┆ master  ┆ s.org/K ┆         │
# │         ┆ /2p2B2/ ┆ c4d3    ┆        ┆         ┆         ┆         ┆ middleg ┆ ite8I8w ┆         │
# │         ┆ P1…     ┆         ┆        ┆         ┆         ┆         ┆ am…     ┆ #4…     ┆         │
# │ zzzLK   ┆ rn2k2r/ ┆ b8d7    ┆ 1794   ┆ 76      ┆ 94      ┆ 8337    ┆ crushin ┆ https:/ ┆ Slav_De │
# │         ┆ pb3ppp/ ┆ c3b5    ┆        ┆         ┆         ┆         ┆ g long  ┆ /liches ┆ fense   │
# │         ┆ 1p1qpn2 ┆ d6b8    ┆        ┆         ┆         ┆         ┆ middleg ┆ s.org/s ┆ Slav_De │
# │         ┆ /3p4/3P ┆ a1c1    ┆        ┆         ┆         ┆         ┆ ame     ┆ VDZKwQJ ┆ fense_O │
# │         ┆ 4/…     ┆ e8g8    ┆        ┆         ┆         ┆         ┆ quiet…  ┆ /b…     ┆ the…    │
# │         ┆         ┆ b5c7    ┆        ┆         ┆         ┆         ┆         ┆         ┆         │
# │ zzzOI   ┆ 8/6p1/8 ┆ g7g6    ┆ 1939   ┆ 82      ┆ 93      ┆ 4349    ┆ crushin ┆ https:/ ┆ null    │
# │         ┆ /2pK3p/ ┆ d5c6    ┆        ┆         ┆         ┆         ┆ g defen ┆ /liches ┆         │
# │         ┆ 1k5P/1P ┆ c5c4    ┆        ┆         ┆         ┆         ┆ siveMov ┆ s.org/f ┆         │
# │         ┆ 4P1/8/8 ┆ b3c4    ┆        ┆         ┆         ┆         ┆ e endga ┆ 1RiiSwW ┆         │
# │         ┆ b…      ┆ b4c4    ┆        ┆         ┆         ┆         ┆ me…     ┆ /b…     ┆         │
# │         ┆         ┆ c6d6    ┆        ┆         ┆         ┆         ┆         ┆         ┆         │
# │ zzzRN   ┆ 4r2k/1N ┆ g1h1    ┆ 826    ┆ 109     ┆ 67      ┆ 33      ┆ endgame ┆ https:/ ┆ null    │
# │         ┆ R2Q1p/4 ┆ e3e1    ┆        ┆         ┆         ┆         ┆ mate    ┆ /liches ┆         │
# │         ┆ P1n1/pp ┆ f7f1    ┆        ┆         ┆         ┆         ┆ mateIn2 ┆ s.org/8 ┆         │
# │         ┆ 1p4/3P4 ┆ e1f1    ┆        ┆         ┆         ┆         ┆ short   ┆ OHS8UmY ┆         │
# │         ┆ /4…     ┆         ┆        ┆         ┆         ┆         ┆         ┆ #6…     ┆         │
# │ zzzTs   ┆ r2qrk2/ ┆ g5c1    ┆ 1848   ┆ 75      ┆ 92      ┆ 946     ┆ advanta ┆ https:/ ┆ Queens_ │
# │         ┆ pb1n1pp ┆ d5d6    ┆        ┆         ┆         ┆         ┆ ge midd ┆ /liches ┆ Gambit_ │
# │         ┆ Q/1p2p3 ┆ d7f6    ┆        ┆         ┆         ┆         ┆ legame  ┆ s.org/8 ┆ Decline │
# │         ┆ /2pP2b1 ┆ h7h8    ┆        ┆         ┆         ┆         ┆ short   ┆ SAGnBjb ┆ d Queen │
# │         ┆ /3…     ┆         ┆        ┆         ┆         ┆         ┆         ┆ /b…     ┆ s_…     │
# │ zzzUZ   ┆ r2qk2r/ ┆ d2f3    ┆ 953    ┆ 98      ┆ 95      ┆ 811     ┆ advanta ┆ https:/ ┆ Sicilia │
# │         ┆ pp2ppbp ┆ d8a5    ┆        ┆         ┆         ┆         ┆ ge fork ┆ /liches ┆ n_Defen │
# │         ┆ /2n3pn/ ┆ c1d2    ┆        ┆         ┆         ┆         ┆ opening ┆ s.org/0 ┆ se Sici │
# │         ┆ 1B1pP3/ ┆ a5b5    ┆        ┆         ┆         ┆         ┆ short   ┆ YzF6l5X ┆ lian_De │
# │         ┆ 3P…     ┆         ┆        ┆         ┆         ┆         ┆         ┆ #1…     ┆ fe…     │
# │ zzzXB   ┆ 1r2r3/p ┆ g7f8    ┆ 1427   ┆ 103     ┆ 88      ┆ 77      ┆ endgame ┆ https:/ ┆ null    │
# │         ┆ 5k1/4p1 ┆ g6g7    ┆        ┆         ┆         ┆         ┆ mate    ┆ /liches ┆         │
# │         ┆ Q1/3p4/ ┆         ┆        ┆         ┆         ┆         ┆ mateIn1 ┆ s.org/T ┆         │
# │         ┆ 7P/5P2/ ┆         ┆        ┆         ┆         ┆         ┆ oneMove ┆ xmghLbN ┆         │
# │         ┆ PP…     ┆         ┆        ┆         ┆         ┆         ┆         ┆ /b…     ┆         │
# │ zzzYp   ┆ 3r1rk1/ ┆ g8h8    ┆ 1072   ┆ 79      ┆ 89      ┆ 593     ┆ crushin ┆ https:/ ┆ null    │
# │         ┆ 3pN1pp/ ┆ e7g6    ┆        ┆         ┆         ┆         ┆ g kings ┆ /liches ┆         │
# │         ┆ nq3pn1/ ┆ h7g6    ┆        ┆         ┆         ┆         ┆ ideAtta ┆ s.org/Y ┆         │
# │         ┆ 1pp1p1Q ┆ g5g6    ┆        ┆         ┆         ┆         ┆ ck      ┆ c8Fdtc0 ┆         │
# │         ┆ N/…     ┆         ┆        ┆         ┆         ┆         ┆ middle… ┆ /b…     ┆         │
# │ zzzc4   ┆ 3r3k/p5 ┆ g1f1    ┆ 1007   ┆ 77      ┆ 89      ┆ 372     ┆ mate    ┆ https:/ ┆ null    │
# │         ┆ pp/8/5R ┆ d8d1    ┆        ┆         ┆         ┆         ┆ mateIn2 ┆ /liches ┆         │
# │         ┆ 2/1BQ1p ┆ b4e1    ┆        ┆         ┆         ┆         ┆ middleg ┆ s.org/j ┆         │
# │         ┆ 3/P3q3/ ┆ e3e1    ┆        ┆         ┆         ┆         ┆ ame     ┆ RTmvh6y ┆         │
# │         ┆ Bb…     ┆         ┆        ┆         ┆         ┆         ┆ short   ┆ #5…     ┆         │
# │ zzzco   ┆ 5Q2/pp3 ┆ f7f2    ┆ 1702   ┆ 75      ┆ 88      ┆ 1082    ┆ endgame ┆ https:/ ┆ null    │
# │         ┆ R1P/1kp ┆ b2c2    ┆        ┆         ┆         ┆         ┆ mate    ┆ /liches ┆         │
# │         ┆ p4/4p3/ ┆ c1b1    ┆        ┆         ┆         ┆         ┆ mateIn2 ┆ s.org/h ┆         │
# │         ┆ 2P1P3/3 ┆ e2d1    ┆        ┆         ┆         ┆         ┆ queensi ┆ ZWTYIAT ┆         │
# │         ┆ PP…     ┆         ┆        ┆         ┆         ┆         ┆ de…     ┆ #6…     ┆         │
# │ zzzfr   ┆ 8/1pp1k ┆ b2b3    ┆ 920    ┆ 77      ┆ 100     ┆ 453     ┆ endgame ┆ https:/ ┆ null    │
# │         ┆ 1p1/p7/ ┆ e5d4    ┆        ┆         ┆         ┆         ┆         ┆ /liches ┆         │
# │         ┆ 2NPb3/4 ┆ f2f3    ┆        ┆         ┆         ┆         ┆         ┆ s.org/z ┆         │
# │         ┆ P3/8/PP ┆ d4c5    ┆        ┆         ┆         ┆         ┆         ┆ Sz3UCjF ┆         │
# │         ┆ 3K…     ┆         ┆        ┆         ┆         ┆         ┆         ┆ #7…     ┆         │
# │ zzzhI   ┆ r3kb1r/ ┆ c6d4    ┆ 2527   ┆ 90      ┆ 86      ┆ 83      ┆ advanta ┆ https:/ ┆ Kings_G │
# │         ┆ ppp2ppp ┆ f1e1    ┆        ┆         ┆         ┆         ┆ ge long ┆ /liches ┆ ambit_A │
# │         ┆ /2n5/3q ┆ e8d8    ┆        ┆         ┆         ┆         ┆ opening ┆ s.org/N ┆ ccepted │
# │         ┆ 3b/3P1B ┆ b1c3    ┆        ┆         ┆         ┆         ┆         ┆ 092KH4f ┆ Kings_G │
# │         ┆ 2/…     ┆ d4f3    ┆        ┆         ┆         ┆         ┆         ┆ /b…     ┆ a…      │
# │         ┆         ┆ g2f3    ┆        ┆         ┆         ┆         ┆         ┆         ┆         │
# │ zzzhg   ┆ r2q1rk1 ┆ g4f5    ┆ 1906   ┆ 76      ┆ 92      ┆ 782     ┆ crushin ┆ https:/ ┆ Queens_ │
# │         ┆ /4bppp/ ┆ e5c6    ┆        ┆         ┆         ┆         ┆ g hangi ┆ /liches ┆ Pawn_Ga │
# │         ┆ p1n1pn2 ┆ f5c2    ┆        ┆         ┆         ┆         ┆ ngPiece ┆ s.org/f ┆ me Quee │
# │         ┆ /1p1pN3 ┆ c6d8    ┆        ┆         ┆         ┆         ┆ long    ┆ 4w3Ljxp ┆ ns_Pawn │
# │         ┆ /2…     ┆ c2b1    ┆        ┆         ┆         ┆         ┆ mid…    ┆ /b…     ┆ _G…     │
# │         ┆         ┆ d8c6    ┆        ┆         ┆         ┆         ┆         ┆         ┆         │
# │ zzzjt   ┆ 7r/kpq2 ┆ c6a5    ┆ 1176   ┆ 75      ┆ 93      ┆ 579     ┆ advance ┆ https:/ ┆ null    │
# │         ┆ p2/2n1p ┆ b5b6    ┆        ┆         ┆         ┆         ┆ dPawn   ┆ /liches ┆         │
# │         ┆ 1p1/1PP ┆ a7b8    ┆        ┆         ┆         ┆         ┆ advanta ┆ s.org/B ┆         │
# │         ┆ 5/4pP2/ ┆ b6c7    ┆        ┆         ┆         ┆         ┆ ge endg ┆ i2ADEmQ ┆         │
# │         ┆ P3…     ┆         ┆        ┆         ┆         ┆         ┆ ame…    ┆ /b…     ┆         │
# │ zzzpD   ┆ 6k1/6p1 ┆ b5b4    ┆ 1030   ┆ 76      ┆ 100     ┆ 306     ┆ crushin ┆ https:/ ┆ null    │
# │         ┆ /6p1/1R ┆ f4d3    ┆        ┆         ┆         ┆         ┆ g       ┆ /liches ┆         │
# │         ┆ 3nP1/p4 ┆ f2e2    ┆        ┆         ┆         ┆         ┆ endgame ┆ s.org/Y ┆         │
# │         ┆ n2/5P1P ┆ d3b4    ┆        ┆         ┆         ┆         ┆ fork    ┆ C734f9d ┆         │
# │         ┆ /P…     ┆         ┆        ┆         ┆         ┆         ┆ short   ┆ #7…     ┆         │
# │ zzzw8   ┆ 8/p7/2K ┆ d6e4    ┆ 1331   ┆ 74      ┆ 85      ┆ 435     ┆ crushin ┆ https:/ ┆ null    │
# │         ┆ n4/4k1p ┆ d3e4    ┆        ┆         ┆         ┆         ┆ g defen ┆ /liches ┆         │
# │         ┆ 1/6Pp/2 ┆ e5e4    ┆        ┆         ┆         ┆         ┆ siveMov ┆ s.org/2 ┆         │
# │         ┆ PB3P/8/ ┆ c3c4    ┆        ┆         ┆         ┆         ┆ e endga ┆ 6wMVKVI ┆         │
# │         ┆ 8 …     ┆         ┆        ┆         ┆         ┆         ┆ me…     ┆ /b…     ┆         │
# └─────────┴─────────┴─────────┴────────┴─────────┴─────────┴─────────┴─────────┴─────────┴─────────┘>

# %%
#limiter aux 100 premières lignes
raw_data=raw_data.head(20000)

# %%
#affiche la FEN et le GameUrl de la ligne 50
#affiche entièrement le FEN

fen_str = raw_data[50, "FEN"]
display(fen_str)
print(raw_data[50,["PuzzleId"]])
# Out:
# 'r3brk1/5pp1/p1nqpn1p/P2pN3/2pP4/2P1PN2/5PPP/RB1QK2R b KQ - 4 16'
# shape: (1, 1)
# ┌──────────┐
# │ PuzzleId │
# │ ---      │
# │ str      │
# ╞══════════╡
# │ 002IE    │
# └──────────┘

# %%
useless_col=["GameUrl","Rating","RatingDeviation","NbPlays","OpeningTags"]
raw_data = raw_data.drop(useless_col)
# Ajoute la colonne "n_moves" à chaque ligne
raw_data = raw_data.with_columns(
    pl.col("Moves").str.split(" ").list.len().alias("n_moves")
)

# %%
distribution = (
    raw_data.group_by("n_moves")
    .len()  # Dans les versions récentes de Polars, .len() remplace .count()
    .sort("n_moves")
)

# Optionnel : Si vous voulez un affichage plus "propre" ligne par ligne
for row in distribution.iter_rows(named=True):
   print(f"{row['n_moves']} coups : {row['len']} problèmes")
# Out:
# 2 coups : 2914 problèmes
# 4 coups : 10238 problèmes
# 6 coups : 5189 problèmes
# 8 coups : 1169 problèmes
# 10 coups : 333 problèmes
# 12 coups : 108 problèmes
# 14 coups : 27 problèmes
# 16 coups : 10 problèmes
# 18 coups : 9 problèmes
# 20 coups : 3 problèmes

# %%
#filter to keep only positions with less than 14 moves
filtered_data = raw_data.filter(pl.col("n_moves") < 10)

# %%
useless_themes = ["bishopEndgame", "endgame", "enPassant", "knightEndgame", "long", "master", 
                  "masterVsMaster", "middlegame", "oneMove", "opening", "pawnEndgame", 
                  "queenEndgame", "queenRookEndgame", "rookEndgame", "short", "superGM", 
                  "veryLong", "mix", "playerGames", "puzzleDownloadInformation","mat","castling","promotion","underpromotion"]

#retirer les lignes où tous les thèmes sont dans useless_themes
filtered_data = (
    filtered_data
    .with_columns(pl.col("Themes").str.split(" ")) 
    .filter(
        pl.col("Themes").list.set_difference(useless_themes).list.len() > 0
    )
)

# %%
# Compte le nombre de positions par thème
theme_distribution = (
    filtered_data
    .explode("Themes")
    .group_by("Themes")
    .len()
    .sort("len", descending=True)
)

for row in theme_distribution.iter_rows(named=True):
   print(f"{row['Themes']} : {row['len']} problèmes")

#fait uen liste des thèmes avec moins de 10 problèmes
themes_to_remove = [row['Themes'] for row in theme_distribution.iter_rows(named=True) if row['len'] < 10]
themes_to_remove = list(set(themes_to_remove) - set(useless_themes))
print("Thèmes à retirer (moins de 10 problèmes):", themes_to_remove)

#pour chaque ligne, retirer les thèmes avec moins de 10 problèmes ou useless
final_data = filtered_data.with_columns(
    pl.col("Themes").list.filter(~pl.element().is_in(themes_to_remove+useless_themes))
).filter(pl.col("Themes").list.len() > 0)
# Out:
# short : 10202 problèmes
# endgame : 9593 problèmes
# middlegame : 8839 problèmes
# crushing : 7362 problèmes
# mate : 6344 problèmes
# advantage : 5674 problèmes
# long : 5155 problèmes
# oneMove : 2914 problèmes
# mateIn1 : 2905 problèmes
# master : 2725 problèmes
# mateIn2 : 2715 problèmes
# fork : 2524 problèmes
# kingsideAttack : 1745 problèmes
# sacrifice : 1424 problèmes
# defensiveMove : 1177 problèmes
# veryLong : 1160 problèmes
# pin : 1138 problèmes
# advancedPawn : 1092 problèmes
# rookEndgame : 1054 problèmes
# discoveredAttack : 1002 problèmes
# opening : 991 problèmes
# deflection : 750 problèmes
# hangingPiece : 749 problèmes
# quietMove : 726 problèmes
# backRankMate : 683 problèmes
# attraction : 646 problèmes
# mateIn3 : 639 problèmes
# pawnEndgame : 637 problèmes
# exposedKing : 579 problèmes
# promotion : 403 problèmes
# discoveredCheck : 401 problèmes
# skewer : 389 problèmes
# queensideAttack : 292 problèmes
# bishopEndgame : 261 problèmes
# pillsburysMate : 259 problèmes
# clearance : 252 problèmes
# masterVsMaster : 252 problèmes
# operaMate : 241 problèmes
# queenEndgame : 231 problèmes
# intermezzo : 228 problèmes
# trappedPiece : 207 problèmes
# zugzwang : 182 problèmes
# queenRookEndgame : 174 problèmes
# knightEndgame : 163 problèmes
# attackingF2F7 : 160 problèmes
# doubleCheck : 116 problèmes
# capturingDefender : 113 problèmes
# smotheredMate : 88 problèmes
# mateIn4 : 85 problèmes
# interference : 70 problèmes
# xRayAttack : 54 problèmes
# equality : 51 problèmes
# cornerMate : 43 problèmes
# hookMate : 38 problèmes
# enPassant : 32 problèmes
# morphysMate : 31 problèmes
# anastasiaMate : 22 problèmes
# arabianMate : 22 problèmes
# triangleMate : 19 problèmes
# dovetailMate : 17 problèmes
# blindSwineMate : 15 problèmes
# killBoxMate : 15 problèmes
# castling : 12 problèmes
# bodenMate : 12 problèmes
# vukovicMate : 12 problèmes
# doubleBishopMate : 10 problèmes
# superGM : 9 problèmes
# balestraMate : 8 problèmes
# underPromotion : 3 problèmes
# Thèmes à retirer (moins de 10 problèmes): ['underPromotion', 'balestraMate']

# %%
# 1. On récupère la liste unique des thèmes
all_themes = final_data.select(pl.col("Themes").explode()).unique().sort("Themes").to_series().to_list()
theme_to_index = {theme: idx for idx, theme in enumerate(all_themes)}

# 2. On transforme la colonne "Themes" en une matrice NumPy (One-Hot Encoding multi-label)
# On utilise une liste de listes temporaire pour la conversion vers NumPy
def create_label_matrix(series, theme_map):
    num_rows = len(series)
    num_labels = len(theme_map)
    # On crée une matrice de zéros avec NumPy
    matrix = np.zeros((num_rows, num_labels), dtype=np.int64)
    
    for i, themes in enumerate(series):
        for theme in themes:
            if theme in theme_map:
                matrix[i, theme_map[theme]] = 1
    return matrix

# Extraction de la colonne "Themes" vers NumPy
# 1. Générer la matrice NumPy (comme on l'a fait avant)
themes_series = final_data["Themes"].to_list()
y_matrix = create_label_matrix(themes_series, theme_to_index)

# 2. L'ajouter au DataFrame proprement
# On convertit la matrice NumPy en une liste de listes pour que Polars l'accepte
filtered_data = filtered_data.with_columns(
    pl.Series("theme_vector", y_matrix.tolist())
)

# %%
#crée une fonction qui transforme une position plus un mouvemement en une nouvelle position FEN
def apply_move_to_fen(fen, move_uci):
    """
    Applique un mouvement à une position donnée en FEN et retourne la nouvelle position en FEN.
    
    Args:
        fen (str): Position en notation FEN
        move_uci (str): Mouvement en notation UCI (ex: 'e2e4')
        
    Returns:
        str: Nouvelle position en notation FEN après application du mouvement
    """
    board = chess.Board(fen)
    move = chess.Move.from_uci(move_uci)
    
    if move in board.legal_moves:
        board.push(move)
        return board.fen()
    else:
        raise ValueError("Mouvement illégal pour la position donnée.")

# %%
#pour chaque ligne, crée une nouvelle colonne "all_FEN" qui correspond à une liste de toutes les positions FEN obtenues après chaque mouvement
def generate_all_fens(fen, moves):
    move_list = moves.split(" ")
    fens = [fen]
    current_fen = fen
    
    for move in move_list:
        current_fen = apply_move_to_fen(current_fen, move)
        fens.append(current_fen)
    
    return fens

filtered_data = filtered_data.with_columns(
    pl.struct(["FEN", "Moves"])
    .map_elements(
        lambda x: generate_all_fens(x["FEN"], x["Moves"]), 
        return_dtype=pl.List(pl.Utf8)  # On précise que la fonction renvoie une liste de chaînes (FENs)
    )
    .alias("all_FEN")
)

# %%
#pour chaque position crée un tensor qui décrit les noeuds (cases du plateau)
"""
0-5,Type de pièce,"[1,0,0,0,0,0] pour un Pion, [0,0,0,0,1,0] pour une Reine"
6,Couleur,"1 (Blanc), -1 (Noir), 0 (Vide)"
7-8,"Position x,y","0.12, 0.50 (coordonnées normalisées entre 0 et 1)"
9,Sécurité,Score d'attaquants vs défenseurs (ex: -0.2)
"""
# crée un tensor qui représente les noeuds controlés par chaque pièce
"0 case de départ des attaqus"
"1 case ciblée par les attaques"



def create_position_tensor(fen):
    """
    Crée un tensor représentant une position d'échecs à partir d'un FEN.
    
    Args:
        fen (str): Position en notation FEN
        
    Returns:
        tuple: (node_features, edge_index)
            - node_features: Tensor de forme (64, 10) pour les caractéristiques des cases
            - edge_index: Tensor de forme (2, N) pour les arêtes (attaques)
    """
    board = chess.Board(fen)
    
    # Initialiser le tensor des noeuds (64 cases, 10 features)
    node_features = torch.zeros((64, 10), dtype=torch.float32)
    
    # Mapping des types de pièces
    piece_type_map = {
        chess.PAWN: [1, 0, 0, 0, 0, 0],
        chess.KNIGHT: [0, 1, 0, 0, 0, 0],
        chess.BISHOP: [0, 0, 1, 0, 0, 0],
        chess.ROOK: [0, 0, 0, 1, 0, 0],
        chess.QUEEN: [0, 0, 0, 0, 1, 0],
        chess.KING: [0, 0, 0, 0, 0, 1]
    }
    
    # Remplir les features des noeuds
    for square in chess.SQUARES:
        piece = board.piece_at(square)
        
        # Type de pièce (indices 0-5)
        if piece:
            node_features[square, 0:6] = torch.tensor(piece_type_map[piece.piece_type])
        
        # Couleur (indice 6)
        if piece:
            node_features[square, 6] = 1.0 if piece.color == chess.WHITE else -1.0
        else:
            node_features[square, 6] = 0.0
        
        # Position x, y normalisées (indices 7-8)
        file = chess.square_file(square)  # 0-7
        rank = chess.square_rank(square)  # 0-7
        node_features[square, 7] = file / 7.0  # Normaliser entre 0 et 1
        node_features[square, 8] = rank / 7.0
        
        # Sécurité: score d'attaquants vs défenseurs (indice 9)
        # 1. Définition des constantes de valeur (à mettre hors de la boucle si possible)
        PIECE_VALUES = {
            chess.PAWN: 1, chess.KNIGHT: 3, chess.BISHOP: 3,
            chess.ROOK: 5, chess.QUEEN: 9, chess.KING: 100
        }

        # --- REMPLACER VOTRE BLOC PAR CELUI-CI ---

        piece = board.piece_at(square)
        if piece:
            # Paramètres de base
            my_color = piece.color
            opp_color = not my_color
            val_piece = PIECE_VALUES[piece.piece_type]
            is_my_turn = (board.turn == my_color)

            # Récupération des attaquants et défenseurs
            atk_set = board.attackers(opp_color, square)
            def_set = board.attackers(my_color, square)
            
            if not atk_set:
                # Cas 1 : Aucune menace directe
                safety_score = 1.0
            else:
                # Trouver l'attaquant le moins cher (LVA)
                min_atk_val = min(PIECE_VALUES[board.piece_at(s).piece_type] for s in atk_set)
                
                if not def_set:
                    # Cas 2 : Attaquée et non défendue (En l'air)
                    safety_score = -1.0 if not is_my_turn else -0.5
                elif min_atk_val < val_piece:
                    # Cas 3 : Menace de gain matériel (ex: Pion attaque Tour)
                    safety_score = -0.8 if not is_my_turn else -0.4
                elif len(atk_set) > len(def_set):
                    # Cas 4 : Surnombre d'attaquants
                    safety_score = -0.6 if not is_my_turn else -0.2
                else:
                    # Cas 5 : Protégée et échange a priori neutre ou défavorable pour l'ennemi
                    safety_score = 0.4 if is_my_turn else 0.1
        else:
            # Case vide
            safety_score = 0.0

        node_features[square, 9] = safety_score
    
    # Créer les arêtes (edge_index) pour les attaques
    edge_list = []
    
    for square in chess.SQUARES:
        piece = board.piece_at(square)
        if piece:
            # Obtenir toutes les cases attaquées par cette pièce
            attacks = board.attacks(square)
            
            for target_square in attacks:
                target_piece = board.piece_at(target_square)
                
                # Ajouter une arête de la case source vers la case cible
                edge_list.append([square, target_square])
    
    # Convertir en tensor de forme (2, N)
    if edge_list:
        edge_index = torch.tensor(edge_list, dtype=torch.long).t()
    else:
        edge_index = torch.zeros((2, 0), dtype=torch.long)
    
    return node_features, edge_index

# %%
def combine_position_and_tactical_info(nodes, edges):
    """
    Combine les caractéristiques des positions avec l'influence tactique.
    
    Args:
        nodes (Tensor): Caractéristiques des noeuds de forme (64, 10)
        edges (Tensor): Arêtes de forme (2, N)
        
    Returns:
        Tensor: Caractéristiques combinées prêtes pour le Transformer
    """
    # On projette les 10 features vers 64 dimensions (d_model standard)
    projection = nn.Linear(10, 64) 
    node_embeddings = projection(nodes) # Résultat: [64, 64]

    
    num_nodes = nodes.size(0)
    # sources: qui attaque, targets: qui est attaqué
    sources, targets = edges[0], edges[1]
    
    # On récupère les caractéristiques des attaquants
    source_features = nodes[sources] 
    
    # On additionne les caractéristiques des attaquants sur la case cible
    # Pour chaque case (0-63), on somme les vecteurs des pièces qui l'attaquent
    tactical_influence = torch.zeros_like(nodes)
    tactical_influence.index_add_(0, targets, source_features)# [64, 10]
    # On combine la position actuelle et l'influence tactique

    combined_features = torch.cat([nodes, tactical_influence], dim=-1) # [64, 20]

    

    return combined_features

# %%
def fen_to_transformer_input(fen):
    """
    Convertit une position FEN en entrée pour un modèle Transformer.
    
    Args:
        fen (str): Position en notation FEN
        
    Returns:
        Tensor: Entrée de forme (64, 20) pour le Transformer
    """
    nodes, edges = create_position_tensor(fen)
    
    # Combine les informations de position et tactiques
    combined_features = combine_position_and_tactical_info(nodes, edges)
    
    return combined_features.detach().cpu().numpy().tolist()

# %%
#apply fen_to_transformers_input au df
filtered_data = filtered_data.with_columns(
    pl.col("all_FEN")
    .map_elements(lambda fen_list: [fen_to_transformer_input(fen) for fen in fen_list], return_dtype=pl.List(pl.List(pl.List(pl.Float32))))
    .alias("all_tensor")
)

# %%
# --- CONSTANTES PRÉ-CALCULÉES ---
_COORDS = np.array([[ (s % 8) / 7.0, (s // 8) / 7.0] for s in range(64)], dtype=np.float32)
VAL_ARRAY = np.array([0, 1, 3, 3, 5, 9, 100], dtype=np.float32)

def fast_create_position_tensor(board):
    """Calcule le tenseur (64, 20) pour l'état actuel du board."""
    node_features = np.zeros((64, 10), dtype=np.float32)
    node_features[:, 7:9] = _COORDS
    
    piece_map = board.piece_map()
    sources, targets = [], []

    for square, piece in piece_map.items():
        p_type, p_color = piece.piece_type, piece.color
        node_features[square, p_type - 1] = 1.0
        node_features[square, 6] = 1.0 if p_color else -1.0
        
        # Sécurité (9) via Bitboards
        atk_mask = board.attackers_mask(not p_color, square)
        if not atk_mask:
            safety = 1.0
        else:
            min_atk_val = 100
            for pt in range(1, 7):
                if atk_mask & board.pieces_mask(pt, not p_color):
                    min_atk_val = VAL_ARRAY[pt]
                    break
            
            def_mask = board.attackers_mask(p_color, square)
            is_my_turn = (board.turn == p_color)
            if def_mask == 0:
                safety = -1.0 if not is_my_turn else -0.5
            elif min_atk_val < VAL_ARRAY[p_type]:
                safety = -0.8 if not is_my_turn else -0.4
            elif atk_mask.bit_count() > def_mask.bit_count():
                safety = -0.6 if not is_my_turn else -0.2
            else:
                safety = 0.4 if is_my_turn else 0.1
        node_features[square, 9] = safety

        # Edges
        move_mask = board.attacks_mask(square)
        targets.extend(list(chess.SquareSet(move_mask)))
        sources.extend([square] * move_mask.bit_count())

    # Influence Tactique
    nodes_t = torch.from_numpy(node_features)
    tactical_influence = torch.zeros((64, 10), dtype=torch.float32)
    if sources:
        tactical_influence.index_add_(0, torch.tensor(targets), nodes_t[sources])
    
    return torch.cat([nodes_t, tactical_influence], dim=-1).numpy()

def generate_game_tensors(fen, moves_string):
    """
    Transforme une partie complète directement en une liste de tenseurs.
    """
    board = chess.Board(fen)
    moves = moves_string.split() if moves_string else []
    
    # 1. Tenseur de la position initiale
    results = [fast_create_position_tensor(board).tolist()]
    
    # 2. Tenseurs pour chaque coup joué
    for move_uci in moves:
        try:
            board.push_uci(move_uci)
            results.append(fast_create_position_tensor(board).tolist())
        except ValueError:
            # En cas de coup invalide, on duplique la position précédente pour garder la longueur
            results.append(results[-1])
            
    return results

# --- APPLICATION POLARS ---
final_data = filtered_data.with_columns(
    all_tensor = pl.struct(["FEN", "Moves"]).map_elements(
        lambda x: generate_game_tensors(x["FEN"], x["Moves"]),
        return_dtype=pl.List(pl.List(pl.List(pl.Float32)))
    )
)

# %%
#sauvegarde le dataframe final
final_data.write_parquet("data/processed/position_classifier_data.parquet")

#sauvegarde le mapping thème-index
# Ensure the directory exists before running this
with open("data/processed/theme_to_index.json", "w") as f:
    json.dump(theme_to_index, f, indent=4) # Added indent for readability
